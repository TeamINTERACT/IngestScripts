# %%
# %matplotlib inline
import os
import subprocess as sub
from datetime import datetime, timedelta
import sqlite3
from itertools import combinations

import dateparser
import matplotlib.pyplot as plt
import psycopg2
import psycopg2.extras
import matplotlib
from tabulate import tabulate
from dotenv import load_dotenv

load_dotenv()

# Environment variables like INGEST_WAVE and INGEST_CITY should be set 
# in your .env file before running. See example.env for intended variables

# expects to find connection credentials in local runtime environment
db_host=os.environ['SQL_LOCAL_SERVER']
db_host_port=int(os.environ['SQL_LOCAL_PORT'])
db_user=os.environ['SQL_USER']
city_num=int(os.environ['INGEST_CITY'])
wave_num=int(os.environ['INGEST_WAVE'])
db_name=os.environ['DB_NAME']
db_schema=os.environ['DB_SCHEMA']

city_data = {1:{'prefix':'vic', 'name':'Victoria'},
             2:{'prefix':'van', 'name':'Vancouver'},
             3:{'prefix':'ssk', 'name':'Saskatoon'},
             4:{'prefix':'mtl', 'name':'Montreal'}}

# these should be derivable from above settings
wavenumstr = f"{wave_num:02}"
city_prefix = city_data[city_num]['prefix']
city_name = city_data[city_num]['name']
datadir = f"/scratch/lazarou/test_pipeline/permanent_archive/{city_name}/Wave{int(wavenumstr)}/SenseDoc"
telemetrydir = f"{datadir}/{city_name.lower()}_{wavenumstr}"
linkage_file = f"{datadir}/../linkage.csv"

# Create a list of users who are to be specifically excluded from a particular study
# It's being done this way because the linkage CSV files do not encode anything about study numbers, and
# adding such a feature would break a lot of code, plus risk contaminating the CSV files through sloppy changes
# So since these cases are rare, I'm putting them here, at the head of the code where they should be 
# obvious and apparent.
suppressors = {} #none needed for Mtl W2


def log(instr):
    timestr = datetime.now().strftime("[%Y-%m-%d %H:%M:%S] ")
    print(f"{timestr}→ {instr}")
    
log(f"Initial parameters registered. You are about to ingest Wave {wave_num} SenseDoc data for the city of {city_name}.")
# Out:
# [2022-11-10 09:54:56] → Initial parameters registered. You are about to ingest Wave 2 SenseDoc data for the city of Montreal.

# %% [markdown]
# **After running the block:** The output line above is telling you which city, wave, and telemetry type you are about to ingest. *Read that line carefully!* If any of it is wrong, you've probably forgotten to set your environment variables correctly. You'll have to shut down Jupyter Lab, update your environment, and then re-launch Jupyter.

# %% [markdown]
# ## Linkage Data
# The first step of ingest is to ensure that all contributing participants have a complete user record in the system that links their interact_id to the sensedoc(s) devices they were assigned, and the time window within which their data was captured. This linkage data needs to be validated and ingested before the telemetry data can be loaded.

# %% [markdown]
# ### Verify Linkage CSV
# This step will assess the CSV file to ensure it's in a parsable format and then confirm that the users listed  match those who have contributed telemetry data. If any errors or mismatches are reported here, the linkage file records should be updated until this verification test passes cleanly.

# %% [markdown]
# #### Possible problems and their solutions
#
# **User in linkage file but has no telemetry data:**
# This can happen when a user was assigned an Ethica account, but either dropped out of the study or switched to SenseDoc before data collection began. If the study coordinator confirms that the user dropped out and produced no usable data, then mark the user with 'ignore' in the data_disposition field of the linkage file. This will exclude them from the list of ids who are expected to have telemetry data.
#
# **User has telemetry data but is not in linkage file:**
# This usually happens when data got collected from a staff member who was testing the system. For these people, there *is* data, but we want to remove it from the ingest. So we don't just ignore these records, we have to actively cull the associated data. This is indicated by marking the data_disposition field with 'cullsd'.

# %%
# Helper Functions: will be used further down to verify the linkage CSV file

import os
import re
import sys
import csv
import subprocess

# In one city, the linkage encode ethica id as 'Ethica ID'
# In another, it is encoded as 'ethica_id'
# We may want to make that column name an input parameter

def validate_iid(idstr, logfailures=True):
    """
    Given an Interact ID in string form, ensure it's well formed.
    Return True if so, False otherwise.
    """
    if not len(idstr.strip()) > 8:
        if logfailures: log(f"Interact ID '{idstr}' is not long enough.")
        return False
    try:
        iid = int(idstr)
    except ValueError:
        if logfailures: log(f"Interact ID '{idstr}' is not an integer.")
        return False
    global iids
    iids.add(iid)
    return True


def validate_eid(idstr, logfailures=True):
    """
    Given an Ethica ID in string form, ensure it's well formed and
    unique. Return True if so, False otherwise.
    """
    try:
        eid = int(idstr)
    except ValueError: # filter B
        if logfailures: log(f"Ethica ID '{idstr}' is not an integer.")
        return False
    global eids
    if eid in eids: # filter A
        if logfailures: log(f"Redundant record for Ethica ID '{idstr}'.")
        return False
    eids.add(str(eid)) 
    # we only converted to int to be sure the string was int-friendly
    # all subsequent tests against id will be done as string compares
    return True


def validate_sdid(instr, logfailures=True):
    """
    Given a SenseDoc ID in string form, ensure it's well formed and unique.
    Return True if so, False otherwise.
    """
    if '-' in instr:
        idstr,dash,revno = instr.partition('-')
        if logfailures: log(f"Extracted {idstr} from {instr}")
    else:
        idstr = instr

    try:
        sdid = int(idstr)
    except ValueError: 
        if logfailures: log(f"SenseDoc ID '{idstr}' is not an integer.")
        return 0
    global sdids
    if sdid in sdids:
        if logfailures: log(f"Redundant record for SenseDoc ID '{idstr}'")
        return 0
    #log(f"SenseDoc ID '{idstr}' is a unique integer.")
    sdids.add(f"{sdid:03}")
    return sdid

def validate_csv_dates(row, colnames):
    """
    Given a CSV record and a list of date columns, 
    ensure the date fields are all present and well-formed.
    Return True if so, False otherwise.
    Wear dates are only valid for SenseDoc data. With SD, data
    capture begins the moment the device is booted, so it captures
    activity of the coordinator prior to delivery to the participant,
    and then again after the device has been recovered. Wear dates
    are used in that situation to filter out the coordinator data.
    (But )Ethica data is different and has no coordinator "pollution"
    that needs to be removed.)
    """
    return True
    try:
        for colname in colnames:
            date_str = row[colname]
            dateval = datetime.strptime(date_str, "%Y-%m-%d")
    except KeyError:
        log(f"EID '{row['ethica_id']}' has missing date field(s)")
        return False
    except ValueError:
        log(f"EID '{row['ethica_id']}' has missing/invalid date info {start_str} - {end_str}")
        return False
    if start_date >= end_date:
        log(f"EID '{row['ethica_id']}' has invalid date window {start_str} - {end_str}")
        return False
    log(f"EID '{row['ethica_id']}' has good date window {start_str} - {end_str}")
    return True


def get_possible_values_from_csv(filename, colnum):
    """
    Given a CSV file and the index number of a column,
    return a list of all unique values in that column
    """
    values = set()
    # To show a helpul progress bar, we have to know how many
    # lines need to be processed, so we need to traverse the file
    # twice. This might seem like overkill, but the data files are
    # pretty big and can take hours to process. Showing signs of
    # life on the console while the script is churning away silently
    # in the background can be very reassuring.
    if os.path.isfile(filename):
        log(f"Scanning file: {filename}")
    else:
        log(f"WARNING: Unable to find file '{filename}'")
        return values
    #nlines = sum(1 for x in open(filename))
    #with open(filename,'r',encoding='ISO-8859-1') as fcsv:
    #    reader = csv.DictReader(fcsv,delimiter=',')
    #    for row in reader:
    #        values.add(row[colname])
            
    # TURNS OUT THE ABOVE IS HORRIBLY INEFFICIENT
    # IT'S ORDERS OF MAGNITUDE FASTER TO RUN A SHELL SCRIPT LIKE THIS:
    # cut -d, -f 1 Ethica/montreal_en_01/raw/gps.csv | sort -u
    
    # set up the piped commands
    skipcmd = ['tail', '-n', '+2', filename] # skip the first line, which has column names
    listuseridscmd = ['cut', '-d,', '-f', colnum] # user_id = first field of each row
    distinctifycmd = ['sort', '-u'] # create a list of distinct ids
    
    # run the piped commands
    p0 = subprocess.Popen(skipcmd, stdout=subprocess.PIPE)
    p1 = subprocess.Popen(listuseridscmd, stdin=p0.stdout, stdout=subprocess.PIPE)
    p2 = subprocess.Popen(distinctifycmd, stdin=p1.stdout, stdout=subprocess.PIPE, encoding='utf8')
    #p1.stdout.close()  # Allow p1 to receive a SIGPIPE if p2 exits.
    output,err = p2.communicate()
    
    # parse the output
    values = []
    for val in output.split('\n'):
        if val: # skip empty lines
            if val.isnumeric():
                values.append(val)
            else:
                log(f"Unexpected non-numeric entry in column {colnum} = '{val}'")

    return values

# Quick test of the above routine
# These are only relevant to Ethica
#log("Testing function: get_possible_values_from_csv()")
#foo = get_possible_values_from_csv(os.path.join(datadir, 'montreal_en_01/raw/gps.csv'), '1')
#log(f"Found {len(foo)} users in English data.")
#foo = get_possible_values_from_csv(os.path.join(datadir, 'montreal_fr_01/raw/gps.csv'), '1')
#log(f"Found {len(foo)} users in French data.")

def detect_missing_values_in_csv(master_values, csvfilelist, colnum, colname, streamname):
    """
    Compare the values in a particular column of a CSV against a
    master list of expected values and report values in the CSV
    that do not match the expectation.
    NOTE: This is only used for Ethica validation, because SenseDoc keeps a unique telemetry
          file for each user.
    """
    found_values = set([])
    for csvfile in csvfilelist:
        studynum = csvfilelist[csvfile]
        log(f"File {csvfile} is associated with study number {studynum}")
        users_in_file = get_possible_values_from_csv(csvfile, colnum)
        for user in users_in_file:
            if user in participant_study and participant_study[user] != studynum:
                log(f"WARNING: User {user} has data in conflicting studies: {studynum} and {participant_study[user]}")
            participant_study[user] = studynum         
        found_values.update(users_in_file)
    
    log(f"Found values: {sorted(list(found_values))}")
    log(f"Master values: {sorted(list(master_values))}")

    missing_values = master_values - found_values - culled_eids
    log(f"{len(master_values)} user_ids found in master linkage CSV")
    log(f"{len(found_values)} distinct ethica_id values found in telemetry CSV data")
    if missing_values: # filter D
        log(f"{len(missing_values)} expected column {colnum} values missing from {streamname} data")
        log(','.join([str(x) for x in sorted(list(missing_values))]))
    else:
        log(f"All expected column {colnum} values found for {streamname}")
    unexpected_values = found_values - master_values
    if unexpected_values: # filter E
        log(f"{len(unexpected_values)} column {colnum} values in {streamname} data were unexpected:")
        log(','.join([str(x) for x in sorted(list(unexpected_values))]))
    else:
        log(f"All values found for column {colnum} in {streamname} were expected")
    log(f"Master values: {sorted(list(master_values))}")
    log(f"Found values: {sorted(list(found_values))}")
    log(f"Missing values: {sorted(list(missing_values))}")
    log(f"Unexpected values: {sorted(list(unexpected_values))}")
    
    
    # ALSO NEED TO POPULATE participant_study BASED ON APPEARANCE IN DATA STREAM
    
    # JUST BEWARE THAT THIS COUNTS THE HEADER ROW AS WELL AS THE DATA ROWS
    
def detect_missing_telemetry_files_for_sensedoc_users(csvfile, telemetry_dir):
    """
    Given a CSV linkage table and a telemetry_dir, create a list of all iid/sdid pairings
    expected (from the csv) and all the pairings present (from the directory), then
    report any missing or unexpected pairings found in either set.
    """
    numiids = len(device_assignments)
    numdirsfound = 0
    numdirsexpected = 0
    
    # Look for device pairings specified in the linkage that are missing from the telemetry directory
    for iid in device_assignments:
        numdirsexpected += len(device_assignments[iid])
        for sdid in device_assignments[iid]:
            pairstring = f"{iid}_{int(sdid):03}"
            user_telemetry_dirname = os.path.join(telemetry_dir, pairstring)
            if not os.path.isdir(user_telemetry_dirname):
                log(f"No telemetry directory found for expected pairing '{pairstring}'")
                continue
            numdirsfound += 1
            # Now see if there's an SDB in that directory with the expected prefix
            r = re.compile(f"SD{int(sdid)}fw.*sdb$")
            telemetry_files = [x for x in os.listdir(user_telemetry_dirname) if r.match(x)]
            if not telemetry_files:
                log(f"No SDB file found for expected pairing '{pairstring}'")
            filepaths_for_ingest.extend([os.path.join(user_telemetry_dirname,x) for x in telemetry_files])
    log(f"Checking {numiids} users and found {numdirsfound} of expected {numdirsexpected} dirs")

    # Now look for device pairings found in the telemetry directory that are not specified in the linkage
    unknown_contributors = []
    unexpected_device_assignments = []
    for file in os.listdir(telemetry_dir):
        if not os.path.isdir(os.path.join(telemetry_dir, file)): # skip non-directories
            continue
        iid,bar,sdid = file.partition('_')
        # log(f"User {iid} produced data on SD {sdid}")
        if iid not in device_assignments:
            unknown_contributors.append(iid)
            #log(f"Unknown data contributor: {iid}")
        else:
            if not sdid in device_assignments[iid]:
                assignment_str = f"{iid}_{int(sdid):03}"
                unexpected_device_assignments.append(assignment_str)
                #log(f"Unexpected telemetry data found for {assignment_str}")
    log(f"There were {len(unknown_contributors)} unexpected contributors:")
    if unknown_contributors:
        log(f"{unknown_contributors}")
    log(f"There were {len(unexpected_device_assignments)} unexpected device assignments found")
    if unexpected_device_assignments:
        log(f"{unexpected_device_assignments}")

    
log("Code has been loaded.")
# Out:
# [2022-11-10 09:55:05] → Code has been loaded.

# %% [markdown]
# **After running the block:** A collection of helper functions have been loaded, but nothing has been executed. The output above should simply confirm that the code has been loaded. If an error was reported, it is most likely either a syntax error in the code or a missing import statement. Whatever it was, that needs to be fixed before continuing.

# %%
# Now parse the linkage file and be sure it's well formed.

ignorables = set([])
usercount = 0
notsensedoc = 0
colnames = ['sensedoc1_wear_start_date', 'sensedoc1_wear_end_date',
            'sensedoc2_wear_start_date', 'sensedoc2_wear_end_date']
iids = set([])
eids = set([])
sdids = set([])
culled_eids = set([])
culled_sdids = set([])
device_assignments = {}
device_wear_windows = {}
filepaths_for_ingest = []
participant_study = {} # a list of which study each participant is registered in


# read the linkage file and validate key data fields
with open(linkage_file,'r',encoding='ISO-8859-1') as fcsv:
    reader = csv.DictReader(fcsv,delimiter=',')
    # optimization, should probably reduce sdid values to set
    # of unique strings first and then validate those
    for rownum,row in enumerate(list(reader)):
        if row['sensedoc1_id'] or row['sensedoc2_id'] or row['interact_id'] or row['ethica_id']:
            usercount += 1
        iid = row['interact_id']
        #log(f"Reading CSV row {rownum}")
        pat = 'sensedoc(?P<index>\d)_id'
        row_sdids = {}
        for key in row.keys():
            m = re.match(pat,key)
            if m:
                index = int(m.group('index'))
                if index and row[key]:
                    sdid = validate_sdid(row[key], logfailures=False)
                    if sdid:
                        row_sdids[index] = sdid
                    else:
                        log(f"Linkage file specifies non-numeric device id '{row[key]}' for user {iid}. Ignoring.")
                        #log(f"{index}th sdid in the row is {row_sdids[index]}")
        if len(row_sdids):
            log(f"User {iid} was assigned {len(row_sdids)} devices")    
        else:
            notsensedoc += 1
            #log(f"CSV row #{rownum} has no sdid")
            continue # we're only interested in sensedoc users
        if not iid.strip() or not validate_iid(iid, logfailures=False): # filter C 
            log(f"Sensedoc user {'/'.join(row_sdids)} has no iid")
            continue
        #log(f"CSV row #{rownum} with iid {iid} has at least one sdid {sdid1} {sdid2}")
        if 'data_disposition' in row.keys():
            if 'cullsd' in row['data_disposition']:
                log(f"Culling SD telemetry data from ethica user {iid}, as instructed by linkage record")
                culled_sdids.update(row_sdids.values())
                # We leave the sdids in the list, so that they will not show up as unexpected ids, 
                # but we also alert the operator that telemetry from this id will be culled at ingest time
            if 'ignore' in row['data_disposition']:
                log(f"Ignoring record for ethica user {eid}, as instructed by linkage record")
                ignorables.update(row_sdids.values()) # keep track of which IDs have been intentionally ignored
                continue
        device_assignments[iid] = []
        for index in row_sdids:
            sdid = row_sdids[index]
            if not validate_csv_dates(row, [f"sensedoc{index}_wear_start_date", f"sensedoc{index}_wear_end_date"]):
                log(f"Problem with date format in CSV, line {rownum}, for the {index}th assignment")
                continue
            device_assignments[iid].append(f"{sdid:03}")
            device_wear_windows[(iid,sdid)] = (row[f"sensedoc{index}_wear_start_date"][:10], row[f"sensedoc{index}_wear_end_date"][:10])

log(f"There were {usercount} participant records in linkage file.")
log(f"{notsensedoc} were not SenseDoc users.")
log(f"{len(device_assignments)} were SenseDoc users with {len(sdids)} distinct devices.")
if len(device_assignments) + notsensedoc == usercount:
    log(f"CONFIRMED: Number of SenseDoc plus non-SenseDoc users equals number of linkage records.")
else:
    log(f"PROBLEM: SenseDoc users and non-SenseDoc users do not add up to number of linkage records.")
log(f"{len(ignorables)} were flagged as 'ignore'. (Probably test users.)")
log(f"{len(culled_sdids)} were flagged as 'cullsd'. (Probably due to known missing or corrupt data.)")

# add the ignorables to the id list so that they will not be
# reported as unexpected
sdids = sdids.union(ignorables)

log(f"There are now {len(sdids)} known SenseDoc ids in the user list.")
if len(device_assignments) >= len(sdids) >= len(device_assignments)/3.0:
    log("CONFIRMED: Number of known device ids seems reasonable.")
elif len(sdids) < len(device_assignments)/3.0:
    log("PROBLEM: Number of known device ids seems unusually low.")
else:
    log("PROBLEM: Number of known device ids seems unusually high.")
log(sorted(sdids))
# Out:
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401000516. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401001678. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401001817. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401002249. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401003098. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401003406. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401003742. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401003807. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401004448. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401004925. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401005392. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401005461. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401007223. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401007394. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401009348. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401009408. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401010101. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401010621. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401010635. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401010886. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401010948. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401010957. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401011719. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401012472. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401012809. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401013270. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401013750. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401014577. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401014707. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401015080. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401015259. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401016019. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401016540. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401017069. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401017127. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401017237. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401017349. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401017776. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401018766. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401020207. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401020737. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401021150. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401023115. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401023308. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401023506. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401024660. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401024667. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401025120. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401025441. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401025830. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401026355. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401026679. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401026863. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401028907. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401029256. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401030156. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401030297. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401031671. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401031801. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401031966. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401032011. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401033425. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401034467. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401034482. Ignoring.
# [2022-11-10 09:55:15] → User 401034573 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401034648. Ignoring.
# [2022-11-10 09:55:15] → User 401035210 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401035551. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401036421. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401037083. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401039270. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401040292. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401040500. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401041455. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401042402. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401043675. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401043881. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401044192. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401046523. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401046986. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401047099. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401047947. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401048287. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401048502. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401048919. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401049804. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401050681. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401051337. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401051850. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401051931. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401052139. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401054561. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401054579. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401054809. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401055246. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401055965. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401056242. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401057435. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401057692. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401058797. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401059246. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401059325. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401059860. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401060274. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401060406. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401060949. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401061984. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401062523. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401063088. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401064054. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401064220. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401064254. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401064425. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401064645. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401065070. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401065721. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401066262. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401067004. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401067457. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401067509. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401068153. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401069576. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401070447. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401071894. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401072219. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401072740. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401077233. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401077819. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401078129. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401078334. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401078649. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401079598. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401080308. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401082835. Ignoring.
# [2022-11-10 09:55:15] → User 401082893 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401083325. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401083647. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401084747. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401085007. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401085103. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401086269. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401086954. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401087007. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401087426. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401087533. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401089674. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401089968. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401091530. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401092815. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401093233. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401093777. Ignoring.
# [2022-11-10 09:55:15] → User 401095730 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401096763. Ignoring.
# [2022-11-10 09:55:15] → User 401097960 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401098180. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401098273. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401098776. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401098878. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401099524. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401101290. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401101486. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401101903. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401102101. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401102511. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401102673. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401103480. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401104058. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401104314. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401104538. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401104729. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401104909. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401105695. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401106176. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401108177. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401108378. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401109640. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401109691. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401111087. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401111807. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401113144. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401113221. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401113754. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401114382. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401114651. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401114865. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401117024. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401117870. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401118275. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401118544. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401118736. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401121183. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401121461. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401123877. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401125503. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401125576. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401126276. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401127024. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401127300. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401127997. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401128162. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401128368. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401128981. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401129083. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401129143. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401130608. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401131404. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401131712. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401132844. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401132911. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401133042. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401133068. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401133536. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401134207. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401136361. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401136961. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401137198. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401137873. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401139426. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401140393. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401141285. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401142217. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401143038. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401143240. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401143447. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401143841. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401144559. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401144618. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401145231. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401145268. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401145591. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401146332. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401146397. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401146874. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401148323. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401148778. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401149339. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401149742. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401151246. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401151515. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401152941. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401153207. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401154165. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401154260. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401156162. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401157310. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401158248. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401159073. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401159599. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401159830. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401159940. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401161018. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401161176. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401162014. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401162732. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401164364. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401165610. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401166787. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401167164. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401167726. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401168982. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401169993. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401170360. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401171397. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401171400. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401171523. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401172157. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401172774. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401173384. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401174334. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401174575. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401175094. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401175437. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401176216. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401176545. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401176972. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401177015. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401177371. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401178032. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401178700. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401180482. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401180544. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401183492. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401183686. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401183820. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401184163. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401184197. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401184341. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401184984. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401185207. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401185827. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401186039. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401186649. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401188567. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401189367. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401189457. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401190000. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401190983. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401191344. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401191377. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401191591. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401193733. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401194946. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401194965. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401196017. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401196235. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401197509. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401197782. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401197924. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401199647. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401199852. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401199969. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401201094. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401201353. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401201805. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401202110. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401202452. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401203454. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401204379. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401205445. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401206271. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401206402. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401206622. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401208005. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401208681. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401209964. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401210141. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401210279. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401210457. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401211139. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401211351. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401211765. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401212334. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401212573. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401213122. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401213323. Ignoring.
# [2022-11-10 09:55:15] → User 401214720 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401214740. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401216016. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401216748. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401217682. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401218229. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401218579. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401219095. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401220048. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401220968. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401221515. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401222648. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401222819. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401223433. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401223566. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401223918. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401225386. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401225779. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401226120. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401226960. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401227067. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401228518. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401230345. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401230429. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401230503. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401231192. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401231657. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401233382. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401233585. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401233723. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401233880. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401233945. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401234514. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401236243. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401236718. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401236761. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401237581. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401238333. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401238720. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401239342. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401239787. Ignoring.
# [2022-11-10 09:55:15] → User 401240419 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401240520. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401240543. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401240768. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401240793. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401241097. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401241197. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401242693. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401243357. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401243995. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401244163. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401244213. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401245025. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401248212. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401248970. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401249230. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401249296. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401249729. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401249937. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401251003. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401252782. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401253228. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401254781. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401256133. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401256729. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401257547. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401257644. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401259422. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401260006. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401263827. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401264485. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401264767. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401264897. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401265811. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401266532. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401267043. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401267357. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401268097. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401268299. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401269173. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401269676. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401270184. Ignoring.
# [2022-11-10 09:55:15] → User 401272178 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401272407. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401272660. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401272903. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401272952. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401273228. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401273284. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401273372. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401273712. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401273784. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401274458. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401274650. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401275453. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401276449. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401277385. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401277679. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401278478. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401278792. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401278829. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401278988. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401279086. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401279419. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401279983. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401281145. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401281267. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401282187. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401282994. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401285374. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401287714. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401288186. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401289051. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401289241. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401291427. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401291566. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401291822. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401291979. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401292777. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401293896. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401295756. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401295931. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401296443. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401296641. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401296820. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401299623. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401299702. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 401300576. Ignoring.
# ...
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402639822. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402645674. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402655598. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402657512. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402659614. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402660349. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402661535. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402662798. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402663817. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402666062. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402667790. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402671765. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402674461. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402679639. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402679810. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402681826. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402682865. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402683645. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402688690. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402691247. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402694238. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402695240. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402695703. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402699152. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402700855. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402704730. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402705029. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402708203. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402709256. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402713179. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402713982. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402724278. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402726036. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402730171. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402731547. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402735951. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402737577. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402737687. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402744787. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402747618. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402750729. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402754651. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402761523. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402764619. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402766833. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402766973. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402767083. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402773739. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402774917. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402776747. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402776953. Ignoring.
# [2022-11-10 09:55:15] → User 402781880 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402782633. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402782703. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402785137. Ignoring.
# [2022-11-10 09:55:15] → User 402789603 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402791731. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402797127. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402798136. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402798573. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402799383. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402800518. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402802569. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402802606. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402804098. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402805897. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402806494. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402806872. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402808952. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402809300. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402817893. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402818602. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402828523. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402828740. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402829657. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402830002. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402832320. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402836807. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402837647. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402839125. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402839717. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402840061. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402841904. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402842078. Ignoring.
# [2022-11-10 09:55:15] → User 402843397 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402844505. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402848094. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402848615. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402851315. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402852882. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402857314. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402871441. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402874641. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402874673. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402874917. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402875593. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402877130. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402877313. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402877538. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402893707. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402902628. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402903603. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402904793. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402905152. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402912901. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402913068. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402913646. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402914779. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402919361. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402921493. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402926660. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402927030. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402929194. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402929366. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402931752. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402934779. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402938231. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402938331. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402942284. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402947557. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402949876. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402950702. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402952770. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402956063. Ignoring.
# [2022-11-10 09:55:15] → User 402958700 was assigned 1 devices
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402960787. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402961262. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402962826. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402963829. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402966064. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402966765. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402968701. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402971256. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402980991. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402981045. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402982067. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402984232. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402984700. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402988240. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402989939. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402991982. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402992482. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402993367. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402996491. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user 402999701. Ignoring.
# [2022-11-10 09:55:15] → Linkage file specifies non-numeric device id 'NA' for user . Ignoring.
# [2022-11-10 09:55:15] → There were 1868 participant records in linkage file.
# [2022-11-10 09:55:15] → 1823 were not SenseDoc users.
# [2022-11-10 09:55:15] → 45 were SenseDoc users with 40 distinct devices.
# [2022-11-10 09:55:15] → CONFIRMED: Number of SenseDoc plus non-SenseDoc users equals number of linkage records.
# [2022-11-10 09:55:15] → 0 were flagged as 'ignore'. (Probably test users.)
# [2022-11-10 09:55:15] → 0 were flagged as 'cullsd'. (Probably due to known missing or corrupt data.)
# [2022-11-10 09:55:15] → There are now 40 known SenseDoc ids in the user list.
# [2022-11-10 09:55:15] → CONFIRMED: Number of known device ids seems reasonable.
# [2022-11-10 09:55:15] → ['006', '023', '036', '039', '045', '049', '050', '051', '060', '063', '069', '077', '095', '096', '102', '103', '117', '121', '122', '144', '158', '165', '166', '167', '169', '173', '174', '189', '201', '204', '205', '235', '237', '241', '246', '253', '256', '280', '283', '293']

# %% [markdown]
# **After running the block:** The output above is telling you how many records were processed in the linkage.csv file, how many were assigned SenseDocs and how many were not. If the number of SenseDoc users and non-SenseDoc users don't add up to the number of user records processed, that will be reported with a PROBLEM line instead of the usual CONFIRMED line. Figure out what's going on before continuing.
#
# Also look at the number of users reported as 'ignore' and 'cullsd'. These are users for whom we do not expect to find telemetry data. Initially, these will probably both be zero, but as we work our way through the process and discover test users, corrupt data, missing data, etc., we will flag those records in the linkage.csv so that the ingest protocol knows how to handle them. Be sure you understand both number reported here and that they make sense to you, before you continue.
#
# Lastly, a count of the unique SenseDoc ids is reported, along with a list of their actual values. Be sure the id numbers look reasonable (usually a 3-digit integer). Also confirm that the number of distinct ids seems reasonable. Usually, it tends to be about 1/2 or 1/3 of the number of total SenseDoc users in the study, but if it seems off to you, consult with the regional coordinator to find out how many physical devices were used in the study. The two numbers should match.

# %%
# And now we can verify the telemetry file against the individual records we just loaded.
detect_missing_telemetry_files_for_sensedoc_users(linkage_file, telemetrydir)

log(f"Found {len(filepaths_for_ingest)} ingestable SDB files")
log("Telemetry files all probed.")
# Users 2032 and 2593 expected to be missing GPS data for Victoria
# Out:
# [2022-11-10 09:55:28] → Checking 45 users and found 45 of expected 45 dirs
# [2022-11-10 09:55:29] → There were 0 unexpected contributors:
# [2022-11-10 09:55:29] → There were 0 unexpected device assignments found
# [2022-11-10 09:55:29] → Found 63 ingestable SDB files
# [2022-11-10 09:55:29] → Telemetry files all probed.

# %% [markdown]
# **After running the block:** Read the output carefully. The first time you run it for a city, it will probably report a number of missing files and directories. This is where we catch the discrepancy between what the linkage file says happened, and what actually happened.
#
# **No SDB file found for...:** This is usually caused by an SDB file that was created but not given the proper filename. Look in the indicated directory for a .sdb file. A properly named file should be in the form SD{DEVICEID}fw{REVNO}_{DATE}_{TIME}.sdb. The **sdb_generate_fname** script can often reconstruct the correct filename, but just as often it fails for the same reasons that the file was originally misnamed. The DEVICEID can be taken from the second half of the folder name; the REVNO may be encoded into some of the other filenames in the directory; and the timestamp info can be extracted from the SDB file using the **sdb_dates** script. Once you've gathered all these elements, rename the SDB file manually to conform to this format.
#
# Also, remember to update the .prvlog sidecar file to point to the new filename.
#
# **No telemetry directory found for expected pairing...:** For some reason, no data was collected from that device assignment. This is usually a case of a directory being misnamed. So look at the 'unexpected contributors'. Chances are good that there's a typo in the directory name that's causing both entries. But if not, consult with the coordinator to see if there are other explanations.

# %% [markdown]
# ### Ingest Linkage
#
# Once the CSV file is known to be valid and complete, we can ingest those records into the sensedoc_assignments table, either adding records or updating them as necessary.

# %%
# Create new users based on records found in linkage file
create_sql = """
    INSERT INTO portal_dev.sensedoc_assignments (interact_id, sensedoc_serial, city_id, wave_id, started_wearing, stopped_wearing)
    VALUES (%s, %s, %s, %s, %s, %s);           
    """

# Open a database session
with psycopg2.connect(user=db_user, host=db_host, port=db_host_port, database=db_name) as conn:
    cur = conn.cursor(cursor_factory=psycopg2.extras.RealDictCursor)
    for iid,sdid in device_wear_windows:
        start_date, end_date = device_wear_windows[(iid,sdid)]
        sql = f"""SELECT count(1) as count from portal_dev.sensedoc_assignments
                  WHERE interact_id = {iid} 
                  AND city_id = {city_num}
                  AND wave_id = {wave_num}
                  AND sensedoc_serial = {sdid};
                  """
        cur.execute(sql)
        row = cur.fetchone()
        if row['count'] == 0:   
            cur.execute(create_sql, (iid, sdid, city_num, wave_num, start_date, end_date))
            if cur.rowcount == 1:
                log(f"Interact User {iid} not previously assigned to SD {sdid} for city {city_num} wave {wave_num}. Created.  ({start_date} - {end_date})")
            else:
                log(f"Problem trying to create participation record for user {iid} with SD {sdid} for city {city_num} wave {wave_num}")
        else:
            log(f"INTERACT USER {iid} ALREADY ASSIGNED TO SD {sdid} FOR CITY {city_num} WAVE {wave_num}") 
            
    # Verify that we have the expected number of assignments for this city/wave
    sql = f"""SELECT count(1) as count from portal_dev.sensedoc_assignments
              WHERE city_id = {city_num}
              AND wave_id = {wave_num};
              """
    cur.execute(sql)
    row = cur.fetchone()
    num_in_db = row['count']
    if num_in_db == len(device_wear_windows):
        log(f"CONFIRMED: Number of SD assignments in DB for city {city_num} wave {wave_num} is as expected ({num_in_db})")
    else:
        log(f"PROBLEM: Expected to find {num_in_db} SD assignments in DB for city {city_num} wave {wave_num} but found {len(device_wear_windows)})")
# Out:
# [2022-11-10 09:55:37] → INTERACT USER 401034573 ALREADY ASSIGNED TO SD 39 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401035210 ALREADY ASSIGNED TO SD 173 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401082893 ALREADY ASSIGNED TO SD 158 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401095730 ALREADY ASSIGNED TO SD 158 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401097960 ALREADY ASSIGNED TO SD 121 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401214720 ALREADY ASSIGNED TO SD 280 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401240419 ALREADY ASSIGNED TO SD 77 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401272178 ALREADY ASSIGNED TO SD 60 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401313041 ALREADY ASSIGNED TO SD 283 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401328714 ALREADY ASSIGNED TO SD 201 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401341482 ALREADY ASSIGNED TO SD 117 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401342134 ALREADY ASSIGNED TO SD 241 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401379272 ALREADY ASSIGNED TO SD 169 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401440362 ALREADY ASSIGNED TO SD 167 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401465378 ALREADY ASSIGNED TO SD 51 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401469801 ALREADY ASSIGNED TO SD 165 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401507474 ALREADY ASSIGNED TO SD 69 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401556493 ALREADY ASSIGNED TO SD 204 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401630460 ALREADY ASSIGNED TO SD 256 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401664309 ALREADY ASSIGNED TO SD 63 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401727775 ALREADY ASSIGNED TO SD 50 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401796474 ALREADY ASSIGNED TO SD 189 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401809607 ALREADY ASSIGNED TO SD 49 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401811306 ALREADY ASSIGNED TO SD 246 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401812917 ALREADY ASSIGNED TO SD 144 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401860045 ALREADY ASSIGNED TO SD 237 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401905412 ALREADY ASSIGNED TO SD 174 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401919451 ALREADY ASSIGNED TO SD 235 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401937896 ALREADY ASSIGNED TO SD 117 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401952301 ALREADY ASSIGNED TO SD 6 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401967217 ALREADY ASSIGNED TO SD 102 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 401967735 ALREADY ASSIGNED TO SD 103 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402141286 ALREADY ASSIGNED TO SD 293 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402178963 ALREADY ASSIGNED TO SD 253 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402312216 ALREADY ASSIGNED TO SD 280 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402402064 ALREADY ASSIGNED TO SD 45 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402411342 ALREADY ASSIGNED TO SD 96 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402435135 ALREADY ASSIGNED TO SD 122 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402463787 ALREADY ASSIGNED TO SD 283 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402495712 ALREADY ASSIGNED TO SD 36 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402577721 ALREADY ASSIGNED TO SD 23 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402781880 ALREADY ASSIGNED TO SD 95 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402789603 ALREADY ASSIGNED TO SD 205 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402843397 ALREADY ASSIGNED TO SD 189 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → INTERACT USER 402958700 ALREADY ASSIGNED TO SD 166 FOR CITY 4 WAVE 2
# [2022-11-10 09:55:37] → CONFIRMED: Number of SD assignments in DB for city 4 wave 2 is as expected (45)

# %% [markdown]
# **After running the block:** The output above will list all new user records added to the DB as well as the records that were not added because they already exist. If you've never run this block before for this city/wave, then most of the records will be new, but if you have, then most/many of them will already exist. What matters is that after executing, the number in the table for this wave/city matches what the linkage file tells us we should have.

# %% [markdown]
# ## Telemetry Data
# Ingesting telemetry data happens in two distinct phases:
# 1. telemetry data from a user's SDB file is copied into a temporary table in the PostgreSQL DB
# 1. the temporary table is copied into the main data table, with interact_ids added and illegal records filterd out
#
# The temporary tables created for a given CITY are:
#  - level_0.{CITY}_w2_sd_gps
#  - level_0.{CITY}_w2_sd_xls

# %% [markdown]
# ### Process Details
#
# Ideally, we want to use the psql COPY command, since it has been
# optimized for fast loading, but the target telemetry table and the
# incoming data file have different column names. We *COULD* just rename
# the columns in the CSV file, but that's a manual step that shouldn't
# be embedded into the process.
#
# So instead, we'll load the data into a temporary table, and then transfer it from there into the target table and match the records to their interact_ids at the same time. This method will more or less double the ingest time, but having a reliable ingest process that can be fully documented, without manual interventions, seems like the more robust path.

# %%
# declare a few ingest-specific functions

# get a list of ethica_ids that are supposed to be culled from the ingest
def get_ids_to_be_culled(csvfilepath):
    culls = set([])
    with open(csvfilepath,'r') as fh:
        reader = csv.DictReader(fh)
        # for each line, determine whether the record already exists
        for record in reader:
            #if 'cullsd' in record['data_disposition'] and not 'ignore' in record['data_disposition']:
                # a record that is both culled and ignored would not have been counted in the expected row count
            if 'cullsd' in record['data_disposition']:    
                culls.add(record['ethica_id'])
    if culls:
        log(f"Ethica IDs to be culled as per linkage file:")
        log(f"{culls}")
    else:
        log("Linkage file includes no cull requests.")
    return culls

def get_ids_to_be_ignored(csvfilepath):
    ignores = set([])
    with open(csvfilepath,'r') as fh:
        reader = csv.DictReader(fh)
        # for each line, determine whether the record already exists
        for record in reader:
            #if 'cullsd' in record['data_disposition'] and not 'ignore' in record['data_disposition']:
                # a record that is both culled and ignored would not have been counted in the expected row count
            if 'ignore' in record['data_disposition']:    
                ignores.add(record['ethica_id'])
    if ignores:
        log(f"Ethica IDs to be ignored as per linkage file:")
        log(f"{ignores}")
    else:
        log("Linkage file includes no ignore requests.")
    return ignores
log("Functions loaded")
# Out:
# [2022-11-10 09:55:37] → Functions loaded

# %% [markdown]
# **After running the block:** Nothing more to do. This one just declares a few useful functions for the ingest process.

# %% [markdown]
# Due to the way they are administered, SenseDoc devices often contain telemetry that was contributed by the project coordinator in addition to tracking the participant. To filter this, each device assignment record includes a start and end date (the wear-date window) to limit the ingest to just data contributed by the intended participant. Consequently, these files have to be very carefully vetted before ingesting. There are 2 things we need to check before accepting the data.
#
# 1) Drop data files that do not contain telemetry data from within the expected wear-date window
# 2) If a user contributes data in more than one file, and the data windows for any of those files overlap, drop all those user's files

# %%
gps_file_row_counts = {}
min_sample_threshold = 3600 #equates to 1 hr of usable data
expected_gps_rows = 0
detect = False # not currently trying to debug a memory leak

def debug(instr):
    if False:
        timestr = datetime.now().strftime("[%H:%M:%S] ")
        print(f"{timestr}→ {instr}")

def select_usable_files(filelist, iidstr):
    """
    Given a list of SDB filepaths for a single participant, perform basic acceptability tests on their contents.
    If the set contains acceptable data, return a list of them. Otherwise, return None.

    The entire set should be considered unacceptable if:
        - the timespans of two or more datafiles overlap
        - the total number of samples across all the files < threshold
    A specific file is removed from consideration if it contains no usable data.
    """

    # Accel tables are MUCH denser and take a lot longer to scan.
    # So to speed up the process, I'm assuming that if the gps table
    # contains good dates and data, the accel table will as well.
    sql_min = "SELECT utcdate from gps order by ts ASC limit 1"
    sql_max = "SELECT utcdate from gps order by ts DESC limit 1"
    sql_n   = "SELECT count(1) as n from gps"

    fstats = []
    for fpath in filelist:
        # open the file and compute its date range and record count
        mindate = 0
        maxdate = 0
        count = 0
        try:
            # log("Connecting to source file %s"% fpath)
            with sqlite3.connect(fpath) as conn:
                c = conn.cursor()

                mindate = 0
                c.execute(sql_min)
                row = c.fetchone()
                if row:
                    mindate = row[0]

                maxdate = 0
                c.execute(sql_max)
                row = c.fetchone()
                if row:
                    maxdate = row[0]

                count = 0
                c.execute(sql_n)
                row = c.fetchone()
                if row:
                    count = int(row[0])

                # hang onto these counts for final stats
                # after the ingest is finished
                gps_file_row_counts[fpath] = count

        except Exception as e:
            log(f"   CAUGHT A SQL ERROR WHILE COUNTING RECORDS: {e}")

        # make a note of those stats if they're usable
        if mindate and maxdate and count:
            log(f"   Keeping {'/'.join(fpath.split('/')[-3:])}")
            fstats.append([mindate,maxdate,count,fpath])
        else: # otherwise leave this file out of the list
            log(f"   Skipping {'/'.join(fpath.split('/')[-3:])} (Unacceptable dates: {mindate}, {maxdate}, {count})")
            
    if len(fstats) > 1:
        # compare all possible pairings of files and reject
        # this filelist if any pair has overlap between
        # their min and max date stamps.
        debug(f"Testing overlaps for {iidstr}")
        for stat1,stat2 in combinations(fstats,2):
            if test_overlapping_daterange(stat1[0], stat1[1],
                                          stat2[0], stat2[1]):
                log(f"   Overlapping timestamps for {iidstr} found between files")
                debug("  %s" % (stat1[3]))
                debug("    %s -> %s"%(stat1[0], stat1[1]))
                debug("    %s -> %s"%(stat2[0], stat2[1]))
                debug("  %s" % (stat2[3]))
                return None
            else:
                debug("Overlap clean.")
        # total the number of samples from all files and
        # reject the filelist if the number of samples does not
        # meet the minimum threshold

        # COULD THIS BE WHERE THE HIGH NUM OF DROPPED ROWS COMING FROM?
        # No, be, because files that get dropped here never get sent
        # to the ingestor, so their counts not added to expected_gps_rows

        contribution = sum([x[2] for x in fstats])
        if contribution < min_sample_threshold:
            log(f"   Not enough samples from participant {iidstr} ({contribution})")
            return None
        return fstats
    elif len(fstats) == 1:
        # if there's only one file, there can't be any overlap
        # so just look at record count
        if fstats[0][2] >= min_sample_threshold:
            return fstats

    log(f"Not enough data from participant {iidstr}")
    return None

def ingest_user_files(iidstr, filepathlist):
    """
    Given an interact_id string and a list of filepaths, perform basic acceptance tests on the data files and
    if they pass, load them into the database, tagged with the iid. Returns True if ingest successful.
    """
    # Perform basic acceptability tests on the candidate files
    # and reject any files that do not meet standards
    ingest_file_stats = select_usable_files(filepathlist, iidstr)

    if not ingest_file_stats:
        log(f"   FILES FOUND WERE NOT USABLE")
        return False

    debug(f"User {iidstr} has ingestible files.")

    # now actually ingest the datafiles
    # not all the sdb files will ingest properly, because some contain duplicate timestamps
    # but as long as one sdb loads cleanly, we will consider this user to be successful
    success = False
    for [min_dt, max_dt, count, sdbfile] in ingest_file_stats:
        result = ingest_sdb_file(sdbfile, city_num, wave_num, iidstr)
        success = success or result

    return success

def test_overlapping_daterange(dt1_st, dt1_end, dt2_st, dt2_end):
    """
    Given the start and end of two different date ranges, determine
    whether the ranges overlap.
    """
    # Make sure each start and end pair are in sorted order
    start1 = min(dt1_st, dt1_end)
    end1 = max(dt1_st, dt1_end)
    start2 = min(dt2_st, dt2_end)
    end2 = max(dt2_st, dt2_end)

    # If one range occurs entirely before the other, there is no overlap.
    # Otherwise there is.
    return not (end1 < start2 or start1 > end2)

def get_participant_wear_dates(iid,city,wave,serial):
    """Given user information, get wear dates from linkage table."""

    # When a sensedoc device gets a new firmware, it is essentially a
    # new device, since it no longer behaves like the old one. To
    # account for this, the ingest code includes both the devid and
    # the revision number as part of the sensedoc_serial number.
    # Unfortunately, the use of the term "serial numbe" is a bit
    # overloaded, so I'm trying to be very careful about which version
    # I'm using in which situation.
    # The sensedoc itself has a record of its serial number, and in
    # that context, it is only revering to the device id portion,
    # without the firmware revision.
    # So in this section of code, I'm going to strip it down and
    # call it the devid.
    if '-' in serial:
        devid = serial.split('-')[0]
    else:
        devid = serial
        log(f"The given serial number ({serial}) was not in compound form.")

    # now we can construct the SQL query
    sql = """
        SELECT  started_wearing as start, stopped_wearing as end
        FROM portal_dev.sensedoc_assignments
        WHERE interact_id = {iid}
        AND city_id = {city}
        AND wave_id = {wave}
        AND sensedoc_serial = {devid};
        """.format(devid=devid,city=city,wave=wave,iid=iid)
    debug(f"Getting wear window with sql: {sql}")
    wear_start = ''
    wear_end = ''
    try:
        with psycopg2.connect(user=db_user,
                            host=db_host,
                            port=db_host_port,
                            database=db_name) as conn:
            c = conn.cursor()
            debug("Looking up participant wear dates with SQL:")
            debug(sql)
            c.execute(sql)
            row = c.fetchone()
            if row:
                # if not (isinstance(row[0], str) or isinstance(row[1], str)):
                # if both date fields have content
                if str(row[0]).strip() and str(row[1]).strip():
                    wear_start = row[0]
                    wear_end = row[1]
                else:
                    log("Empty wear dates for serial: '%s'"%serial)
                debug("Result was:")
                debug(row)
            else:
                log("Unable to find wear dates for serial: '%s'"%serial)
    except Exception as e:
        log(f"SQL CALL FAILED: {e}")
    # The protocol requires that the declared start date in
    # the linkage table be the day the participant actually
    # began wearing the device - not the day they received it.
    # Also assumes the declared final day of wearing includes
    # any data up to 3am of the following day.
    # So to implement this 'look-ahead', we'll
    # advance the wear_end to 03:00 the following day
    if wear_end.strip():
        wear_end = dateparser.parse(wear_end[:10] + " 03:00:00")
        wear_end += timedelta(days=1)
    return wear_start, wear_end


def create_table_prefix(fname, iidstr):
    """
    Given a filename and an iid, combine them to create a compact
    name for a temp table.
    """
    prefix = "%s_" % iidstr
    prefix += ''.join([x for x in fname if x.isalnum()])

    return prefix


def execute_copy_via_shell(filepath, city, wave, iid, serial, tableid, wear_start, wear_end, tablename, selectionsql):
    """
    On the command line we could run a single command to
    pull data from the sqlite file with sqlite3 and ingest into the
    postgres by piping the output directly to psql.

    In simple form, that console command would be:
    sqlite3 somefile.sdb SELECTIONSQL | psql interact_db INSERTSQL

    In the simple form of the command line shown above, the two
    key elements are SELECTIONSQL, which is the SQL fragment used to
    select a table's content out of the target SQLite file, and the
    INSERTSQL, which is the SQL fragment used to load the incoming
    data into the PostgreSQL database.

    Unfortunately, the data is known to contain occasional duplicate
    records, which happen when the SD device syncs its onboard clock
    with the real world. In these cases, the most accurate data for
    that timestamp are the values associated with the last record
    recorded, not the first.

    To drop those redundant timestamps, we have to wait until after
    we've ingested the file, because the /COPY command does not
    permit ON CONFLICT or DISTINCT clauses.

    Furthermore, we can't use ON CONFLICT to drop dups in the main
    table because the main uses a brin index which can't test for
    uniqueness.

    So we load the entire SDB file into a temporary table.
    Then we copy to a second temp table that has a btree index.
    At the same time, we drop any records outside the wear window.
    Then we finally absorb that clean incoming table into the main table.
    """
    
    # Assemble the SQL commands
    full_tablename = f"{db_schema}.{tablename}"
    raw_tablename = f"tmpA_{tableid}"
    filtered_tablename = f"tmpB_{tableid}"
    idx_name = f"tmpB_{tableid}_btree_idx"
    log(f"   Loading tables for {tableid}")
    ingestcmd = f"""
             SET SCHEMA '{db_schema}';
             CREATE TABLE {raw_tablename} (LIKE {tablename});
             CREATE TABLE {filtered_tablename} (LIKE {tablename});
             ALTER TABLE {filtered_tablename} ADD CONSTRAINT {idx_name} UNIQUE (iid,ts);

             -- load the raw table
             COPY {raw_tablename} FROM STDIN delimiter '|' CSV;

             -- copy the raw table to the nodups tbl
             -- while dropping records outside wear window
             -- and dropping duplicate records as well
             INSERT INTO {filtered_tablename}
                SELECT * FROM {raw_tablename}
                WHERE ts >= '{wear_start}'
                AND   ts <= '{wear_end}'
             ON CONFLICT (iid,ts) DO NOTHING;
             
             -- now merge the filtered table into the main table
             INSERT INTO {tablename}
                SELECT * FROM {filtered_tablename};
                
             -- and then clean up the no-longer needed tables
             DROP TABLE IF EXISTS {raw_tablename};
             DROP TABLE IF EXISTS {filtered_tablename};

             -- and commit the transaction, all of which will
             -- be ignored and unrolled if any of the intermediate
             -- steps fail
             COMMIT;
             """

    # NOTE: There's still a minor issue here. We tend to want to ingest
    # an entire wave at a time, but if something goes wrong partway
    # through, we don't have an elegant way to rollback the ingest and
    # start it again. As it stands, running an ingest a second time
    # should work fine, since the INSERT ON CONFLICT will simply ignore
    # records that were already ingested. This will admittedly take up
    # more time, loading all the previously ingested participants
    # only to ignore their records at copy time. But processing the
    # entire wave and ignoring records we already have seems the more
    # robust solution as it is less likely to accidentally omit data
    # by trying to be clever about skipping redundant ingests.

    # Tell sqlite where the temp directory is
    cmdline = 'SQLITE_TMPDIR=~/scratch '

    # Load the raw data into a temp table
    cmdline += f'sqlite3 {filepath} "{selectionsql}" | psql -h {db_host} -p {db_host_port} -U {db_user} -q -e -c "{ingestcmd}" {db_name}'
    debug("Load command line: %s" % cmdline)
    #res = sub.call(cmdline, shell=True)
    res = sub.run(cmdline, shell=True, stderr=sub.PIPE)
    # res = sub.check_output(cmdline, shell=True,stderr=sub.STDOUT)
    # res = res.decode('utf-8').strip()
    if res.returncode:
        # If table load fails, the ingest for that participant
        # should be reported as unsuccessful.
        # But if the error was caused by duplicate time values, it will fail with an 
        # error that contains: duplicate key value violates unique constraint
        # in this case, the user file has indeed failed to load, but it is not
        # an ingest error. In this case, we still return the False, since the
        # file did not ingest, but we should report the situation more clearly.
        if "duplicate key value violates unique constraint" in res.stderr.decode('utf-8'):
            log(f"   SDB FILE CONTAINS DUPLICATE TIME RECORDS. SKIPPING.")
            return False
        else:
            log(f"Ingesting file {filepath} failed with return code: {res.returncode}")
            debug(f"ERR: {res.stderr}")
        return False

    return True 


def ingest_sdb_file(filepath, city, wave, iidstr):
    """
    Given an SDB data file, load its tables into the DB,
    tagged with the iid of the participant who produced it.
    Return True if the file ingests properly, False otherwise.
    """
    refDate = ''
    # We counted file rows when we were validating the files,
    # so now that we know this file is being ingested, add its
    # row count to the total number of rows we're trying to ingest.
    global expected_gps_rows
    if filepath in gps_file_row_counts:
        expected_gps_rows += gps_file_row_counts[filepath]
    else:
        log("   SDB FILE was never row-counted.")

    log("   Ingesting file: %s"%os.path.basename(filepath))
    try:
        with sqlite3.connect(filepath) as conn:
            # get the reference date from the SDB from which all
            # timestamps are measured
            c = conn.cursor()
            sql = "SELECT value FROM ancillary WHERE key='refDate'"
            debug("   Getting refDate with: %s"%sql)
            c.execute(sql)
            refDate = c.fetchone()[0]
            debug("   Got refDate of: %s"%refDate)
    except Exception as e:
        log("   Caught a SQL error while ingesting %s"%filepath)
        log(e)


    if not refDate.strip(): #strip to be sure it isn't just spaces
        log("   Unable to get refDate from file %s"%filepath)
        return False
    # Each table in the SQLite file needs its own SELECT stmt
    # to ensure data is read from the file in a known format.
    selectionsql = {}
    # process gps first so that failures on duplicate entries happen sooner
    # and we avoid processing the more expensive accel table in those cases
    selectionsql['sd_gps'] = f"""
        SELECT '{iidstr}' AS iid,
            strftime('%Y-%m-%d %H:%M:%f', '{refDate}',
                    (ts/1000000.0)||' seconds') as ts,
                lat, lon,
                speed,
                course,
                -- ignoring mode, fix,
                -- ignoring mode1, mode2,
                -- following fields set to NODATA (-9999) if null
                IFNULL(alt,-9999),
                IFNULL(sat_used,-9999),
                IFNULL(pdop,-9999),
                IFNULL(hdop,-9999),
                IFNULL(vdop,-9999),
                IFNULL(sat_in_view,-9999)
            FROM gps
            WHERE   (lat is not null)
                AND (lon is not null)
                AND (lat BETWEEN -90 and 90)
                AND (lon BETWEEN -180 and 180)
                AND (alt is NULL or alt BETWEEN -10000 and 100000)
                AND (course is NULL or course BETWEEN -360 and 360)
                AND (speed is NULL or speed BETWEEN 0 and 1000)
                AND (sat_used is NULL or sat_used BETWEEN 0 and 50)
                AND (sat_in_view is NULL or sat_in_view BETWEEN 0 and 50)
                -- this clause filters out duplicate timestamps
                AND (rowid in (SELECT max(rowid) FROM gps GROUP BY ts))
            ORDER BY ts, ROWID DESC;
        """
    debug(f"SQL for gps:\n{selectionsql['sd_gps']}")
    selectionsql['sd_accel'] = f"""
                       SELECT '{iidstr}' AS iid,
                            strftime('%Y-%m-%d %H:%M:%f', '{refDate}',
                                    (ts/1000000.0)||' seconds') as ts,
                            x * 0.00390625 as x, ---convert to 0.0-1.0
                            y * 0.00390625 as y, ---convert to 0.0-1.0
                            z * 0.00390625 as z  ---convert to 0.0-1.0
                       FROM accel
                       WHERE x is not null
                         AND y is not null
                         AND z is not null
                         -- this clause filters out duplicate times
                         AND rowid in (SELECT max(rowid) FROM accel GROUP BY ts)
                       ORDER BY ts, ROWID DESC;
                       """
    debug(f"SQL for accel:\n{selectionsql['sd_accel']}")
        # NOTE: In the above queries, strftime() is used instead of
        # datetime() because datetime() truncates to seconds, whereas
        # the strftime() with %f keeps fractional seconds.
        # Also note that the .0 is important at the end of 1000000.0,
        # to preserve the floating-point nature of the result.
        # The rows are sorted by ts, and then  ROWID DESC because
        # we need to filter later by the order in which the rows were
        # written to the file, keeping only the latest instance in cases
        # where records share the same timestamp info.


    # based on the name of the file being processed, construct a
    # temporary tablename we can use for loading this data.
    # In some cases, we may want to leave the table around after
    # ingest (for forensic purposes) and if we want that to work
    # each table has to have a unique name.
    # tail = ''
    serial = ''
    basename = os.path.basename(filepath)
    tableprefix = create_table_prefix(basename, iidstr)
    serialpat = "SD(?P<num>\d*)fw(?P<rev>\d*)_(?P<tail>.*)\.sdb"
    m = re.match(serialpat, basename)
    if m:
        if not m.group('num'): # or not m.group('rev'):
            log("   NOTE: Malformed SDB filename: %s is missing device id" % basename)
            return False
        if not m.group('rev'):
            log("   NOTE: Malformed SDB filename: %s is missing OS revision number" % basename)
            return False
        serial = "%s-%s" % (m.group('num'), m.group('rev'))

    # we also need to know the wear dates for this file in order to
    # filter out extraneous records
    # import pdb; pdb.set_trace()
    wear_start, wear_end = get_participant_wear_dates(iidstr, city, wave, serial)
    if not wear_start or not wear_end:
        log("   No wear dates in linkage tbl for user %s city %s wave %s serial %s"%(iidstr, city, wave, serial))
        return False
    else:
        log("   Keeping records within wear dates: %s - %s."%(wear_start,wear_end))

    # Now ingest each of the required tables into the DB.
    success = True
    for main_tbl in selectionsql:
        tableid = '%s_%s' % (tableprefix, main_tbl)
        success = success and execute_copy_via_shell(filepath,
                                            city, wave,
                                            iidstr, serial, tableid,
                                            wear_start, wear_end,
                                            main_tbl,
                                            selectionsql[main_tbl])
    return success


log("Ingesting inventoried files...")
#for iidstr in ["401341482",]:
for n,iidstr in enumerate(iids):
    participant_files = list(set([x for x in filepaths_for_ingest if f"/{iidstr}_" in x])) #find all filepaths for this iid
    if participant_files:
        log(f"Inventory for {iidstr} {n+1}/{len(iids)} holds:")
        for f in participant_files: 
            log(f"   {'/'.join(f.split('/')[-3:])}")
        result = ingest_user_files(iidstr, participant_files)
        if result:
            log("   User contributed useful data")
        else:
            log("   NO USABLE DATA CONTRIBUTED")
            #log("Halting so we can debug the error that just occurred.")
            #break
    else:
        log(f"Inventory ? {iidstr}")
    #debug("Halting after one user to examine trace...")
    #break
log(f"All users' SDB files processed.")
# Out:
# [2022-11-10 09:55:39] → Ingesting inventoried files...
# [2022-11-10 09:55:39] → Inventory for 401214720 1/45 holds:
# [2022-11-10 09:55:39] →    montreal_02/401214720_280/SD280fw2106_20210216_142559_rtc1.sdb
# [2022-11-10 09:55:39] →    montreal_02/401214720_280/SD280fw2106_20210216_142559.sdb
# [2022-11-10 09:55:39] →    Keeping montreal_02/401214720_280/SD280fw2106_20210216_142559_rtc1.sdb
# [2022-11-10 09:55:39] →    Skipping montreal_02/401214720_280/SD280fw2106_20210216_142559.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:55:39] →    Ingesting file: SD280fw2106_20210216_142559_rtc1.sdb
# [2022-11-10 09:55:41] →    Keeping records within wear dates: 2021-01-19 - 2021-01-29 03:00:00.
# [2022-11-10 09:55:41] →    Loading tables for 401214720_SD280fw210620210216142559rtc1sdb_sd_gps
# [2022-11-10 09:55:43] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401214720_280/SD280fw2106_20210216_142559_rtc1.sdb failed with return code: 127
# [2022-11-10 09:55:43] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:55:43] → Inventory for 401905412 2/45 holds:
# [2022-11-10 09:55:43] →    montreal_02/401905412_174/SD174fw2106_20201125_152900.sdb
# [2022-11-10 09:55:43] →    Keeping montreal_02/401905412_174/SD174fw2106_20201125_152900.sdb
# [2022-11-10 09:55:43] →    Ingesting file: SD174fw2106_20201125_152900.sdb
# [2022-11-10 09:55:43] →    Keeping records within wear dates: 2020-10-26 - 2020-11-06 03:00:00.
# [2022-11-10 09:55:43] →    Loading tables for 401905412_SD174fw210620201125152900sdb_sd_gps
# [2022-11-10 09:55:46] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401905412_174/SD174fw2106_20201125_152900.sdb failed with return code: 127
# [2022-11-10 09:55:46] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:55:46] → Inventory for 402843397 3/45 holds:
# [2022-11-10 09:55:46] →    montreal_02/402843397_189/SD189fw2106_20201215_160019.sdb
# [2022-11-10 09:55:46] →    Keeping montreal_02/402843397_189/SD189fw2106_20201215_160019.sdb
# [2022-11-10 09:55:46] →    Ingesting file: SD189fw2106_20201215_160019.sdb
# [2022-11-10 09:55:46] →    Keeping records within wear dates: 2020-11-22 - 2020-12-02 03:00:00.
# [2022-11-10 09:55:46] →    Loading tables for 402843397_SD189fw210620201215160019sdb_sd_gps
# [2022-11-10 09:55:47] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402843397_189/SD189fw2106_20201215_160019.sdb failed with return code: 127
# [2022-11-10 09:55:47] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:55:47] → Inventory for 401082893 4/45 holds:
# [2022-11-10 09:55:47] →    montreal_02/401082893_158/SD158fw2106_20210216_133109.sdb
# [2022-11-10 09:55:47] →    Keeping montreal_02/401082893_158/SD158fw2106_20210216_133109.sdb
# [2022-11-10 09:55:47] →    Ingesting file: SD158fw2106_20210216_133109.sdb
# [2022-11-10 09:55:47] →    Keeping records within wear dates: 2021-01-13 - 2021-01-23 03:00:00.
# [2022-11-10 09:55:47] →    Loading tables for 401082893_SD158fw210620210216133109sdb_sd_gps
# [2022-11-10 09:55:47] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401082893_158/SD158fw2106_20210216_133109.sdb failed with return code: 127
# [2022-11-10 09:55:47] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:55:47] → Inventory for 401556493 5/45 holds:
# [2022-11-10 09:55:47] →    montreal_02/401556493_204/SD204fw2106_20210428_191230.sdb
# [2022-11-10 09:55:47] →    montreal_02/401556493_204/SD204fw2106_20210428_191230_rtc1.sdb
# [2022-11-10 09:55:50] →    Keeping montreal_02/401556493_204/SD204fw2106_20210428_191230.sdb
# [2022-11-10 09:55:50] →    Keeping montreal_02/401556493_204/SD204fw2106_20210428_191230_rtc1.sdb
# [2022-11-10 09:55:50] →    Ingesting file: SD204fw2106_20210428_191230.sdb
# [2022-11-10 09:55:52] →    Keeping records within wear dates: 2020-11-20 - 2020-12-01 03:00:00.
# [2022-11-10 09:55:52] →    Loading tables for 401556493_SD204fw210620210428191230sdb_sd_gps
# [2022-11-10 09:55:52] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401556493_204/SD204fw2106_20210428_191230.sdb failed with return code: 127
# [2022-11-10 09:55:52] →    Ingesting file: SD204fw2106_20210428_191230_rtc1.sdb
# [2022-11-10 09:55:52] →    Keeping records within wear dates: 2020-11-20 - 2020-12-01 03:00:00.
# [2022-11-10 09:55:52] →    Loading tables for 401556493_SD204fw210620210428191230rtc1sdb_sd_gps
# [2022-11-10 09:55:57] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401556493_204/SD204fw2106_20210428_191230_rtc1.sdb failed with return code: 127
# [2022-11-10 09:55:57] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:55:57] → Inventory for 402402064 6/45 holds:
# [2022-11-10 09:55:57] →    montreal_02/402402064_045/SD45fw2106_20201216_113747.sdb
# [2022-11-10 09:55:57] →    Keeping montreal_02/402402064_045/SD45fw2106_20201216_113747.sdb
# [2022-11-10 09:55:57] →    Ingesting file: SD45fw2106_20201216_113747.sdb
# [2022-11-10 09:55:59] →    Keeping records within wear dates: 2020-11-12 - 2020-11-23 03:00:00.
# [2022-11-10 09:55:59] →    Loading tables for 402402064_SD45fw210620201216113747sdb_sd_gps
# [2022-11-10 09:55:59] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402402064_045/SD45fw2106_20201216_113747.sdb failed with return code: 127
# [2022-11-10 09:55:59] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:55:59] → Inventory for 401313041 7/45 holds:
# [2022-11-10 09:55:59] →    montreal_02/401313041_283/SD283fw2106_20201124_173141.sdb
# [2022-11-10 09:56:00] →    Keeping montreal_02/401313041_283/SD283fw2106_20201124_173141.sdb
# [2022-11-10 09:56:00] →    Ingesting file: SD283fw2106_20201124_173141.sdb
# [2022-11-10 09:56:00] →    Keeping records within wear dates: 2020-10-17 - 2020-10-27 03:00:00.
# [2022-11-10 09:56:00] →    Loading tables for 401313041_SD283fw210620201124173141sdb_sd_gps
# [2022-11-10 09:56:02] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401313041_283/SD283fw2106_20201124_173141.sdb failed with return code: 127
# [2022-11-10 09:56:02] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:02] → Inventory for 401507474 8/45 holds:
# [2022-11-10 09:56:02] →    montreal_02/401507474_069/SD69fw2106_20201113_170116.sdb
# [2022-11-10 09:56:02] →    Keeping montreal_02/401507474_069/SD69fw2106_20201113_170116.sdb
# [2022-11-10 09:56:02] →    Ingesting file: SD69fw2106_20201113_170116.sdb
# [2022-11-10 09:56:02] →    Keeping records within wear dates: 2020-10-28 - 2020-11-07 03:00:00.
# [2022-11-10 09:56:02] →    Loading tables for 401507474_SD69fw210620201113170116sdb_sd_gps
# [2022-11-10 09:56:03] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401507474_069/SD69fw2106_20201113_170116.sdb failed with return code: 127
# [2022-11-10 09:56:03] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:03] → Inventory for 402178963 9/45 holds:
# [2022-11-10 09:56:03] →    montreal_02/402178963_253/SD253fw2106_20210224_110405.sdb
# [2022-11-10 09:56:03] →    montreal_02/402178963_253/SD253fw2106_20210224_110405_rtc1.sdb
# [2022-11-10 09:56:04] →    Skipping montreal_02/402178963_253/SD253fw2106_20210224_110405.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:04] →    Keeping montreal_02/402178963_253/SD253fw2106_20210224_110405_rtc1.sdb
# [2022-11-10 09:56:04] →    Ingesting file: SD253fw2106_20210224_110405_rtc1.sdb
# [2022-11-10 09:56:04] →    Keeping records within wear dates: 2020-10-22 - 2020-11-01 03:00:00.
# [2022-11-10 09:56:04] →    Loading tables for 402178963_SD253fw210620210224110405rtc1sdb_sd_gps
# [2022-11-10 09:56:08] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402178963_253/SD253fw2106_20210224_110405_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:08] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:08] → Inventory for 402312216 10/45 holds:
# [2022-11-10 09:56:08] →    montreal_02/402312216_280/SD280fw2106_20201125_121844.sdb
# [2022-11-10 09:56:08] →    Keeping montreal_02/402312216_280/SD280fw2106_20201125_121844.sdb
# [2022-11-10 09:56:08] →    Ingesting file: SD280fw2106_20201125_121844.sdb
# [2022-11-10 09:56:08] →    Keeping records within wear dates: 2020-10-24 - 2020-11-04 03:00:00.
# [2022-11-10 09:56:08] →    Loading tables for 402312216_SD280fw210620201125121844sdb_sd_gps
# [2022-11-10 09:56:09] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402312216_280/SD280fw2106_20201125_121844.sdb failed with return code: 127
# [2022-11-10 09:56:09] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:09] → Inventory for 401727775 11/45 holds:
# [2022-11-10 09:56:09] →    montreal_02/401727775_050/SD50fw2106_20210216_121849.sdb
# [2022-11-10 09:56:09] →    montreal_02/401727775_050/SD50fw2106_20210216_121849_rtc1.sdb
# [2022-11-10 09:56:09] →    Keeping montreal_02/401727775_050/SD50fw2106_20210216_121849.sdb
# [2022-11-10 09:56:10] →    Keeping montreal_02/401727775_050/SD50fw2106_20210216_121849_rtc1.sdb
# [2022-11-10 09:56:10] →    Ingesting file: SD50fw2106_20210216_121849.sdb
# [2022-11-10 09:56:10] →    Keeping records within wear dates: 2020-12-02 - 2020-12-13 03:00:00.
# [2022-11-10 09:56:10] →    Loading tables for 401727775_SD50fw210620210216121849sdb_sd_gps
# [2022-11-10 09:56:10] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401727775_050/SD50fw2106_20210216_121849.sdb failed with return code: 127
# [2022-11-10 09:56:10] →    Ingesting file: SD50fw2106_20210216_121849_rtc1.sdb
# [2022-11-10 09:56:10] →    Keeping records within wear dates: 2020-12-02 - 2020-12-13 03:00:00.
# [2022-11-10 09:56:10] →    Loading tables for 401727775_SD50fw210620210216121849rtc1sdb_sd_gps
# [2022-11-10 09:56:11] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401727775_050/SD50fw2106_20210216_121849_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:11] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:11] → Inventory for 401465378 12/45 holds:
# [2022-11-10 09:56:11] →    montreal_02/401465378_051/SD51fw2106_20210216_150723.sdb
# [2022-11-10 09:56:12] →    Keeping montreal_02/401465378_051/SD51fw2106_20210216_150723.sdb
# [2022-11-10 09:56:12] →    Ingesting file: SD51fw2106_20210216_150723.sdb
# [2022-11-10 09:56:12] →    Keeping records within wear dates: 2020-12-16 - 2020-12-26 03:00:00.
# [2022-11-10 09:56:12] →    Loading tables for 401465378_SD51fw210620210216150723sdb_sd_gps
# [2022-11-10 09:56:18] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401465378_051/SD51fw2106_20210216_150723.sdb failed with return code: 127
# [2022-11-10 09:56:18] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:18] → Inventory for 401341482 13/45 holds:
# [2022-11-10 09:56:18] →    montreal_02/401341482_117/SD117fw2106_20210216_094539_rtc1.sdb
# [2022-11-10 09:56:18] →    montreal_02/401341482_117/SD117fw2106_20210216_094539_rtc2.sdb
# [2022-11-10 09:56:18] →    montreal_02/401341482_117/SD117fw2106_20210216_094539.sdb
# [2022-11-10 09:56:19] →    Keeping montreal_02/401341482_117/SD117fw2106_20210216_094539_rtc1.sdb
# [2022-11-10 09:56:19] →    Keeping montreal_02/401341482_117/SD117fw2106_20210216_094539_rtc2.sdb
# [2022-11-10 09:56:19] →    Skipping montreal_02/401341482_117/SD117fw2106_20210216_094539.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:19] →    Ingesting file: SD117fw2106_20210216_094539_rtc1.sdb
# [2022-11-10 09:56:19] →    Keeping records within wear dates: 2021-01-14 - 2021-01-25 03:00:00.
# [2022-11-10 09:56:19] →    Loading tables for 401341482_SD117fw210620210216094539rtc1sdb_sd_gps
# [2022-11-10 09:56:20] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401341482_117/SD117fw2106_20210216_094539_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:20] →    Ingesting file: SD117fw2106_20210216_094539_rtc2.sdb
# [2022-11-10 09:56:20] →    Keeping records within wear dates: 2021-01-14 - 2021-01-25 03:00:00.
# [2022-11-10 09:56:20] →    Loading tables for 401341482_SD117fw210620210216094539rtc2sdb_sd_gps
# [2022-11-10 09:56:22] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401341482_117/SD117fw2106_20210216_094539_rtc2.sdb failed with return code: 127
# [2022-11-10 09:56:22] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:22] → Inventory for 402463787 14/45 holds:
# [2022-11-10 09:56:22] →    montreal_02/402463787_283/SD283fw2106_20210219_111003.sdb
# [2022-11-10 09:56:22] →    Keeping montreal_02/402463787_283/SD283fw2106_20210219_111003.sdb
# [2022-11-10 09:56:22] →    Ingesting file: SD283fw2106_20210219_111003.sdb
# [2022-11-10 09:56:22] →    Keeping records within wear dates: 2020-12-26 - 2021-01-05 03:00:00.
# [2022-11-10 09:56:22] →    Loading tables for 402463787_SD283fw210620210219111003sdb_sd_gps
# [2022-11-10 09:56:23] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402463787_283/SD283fw2106_20210219_111003.sdb failed with return code: 127
# [2022-11-10 09:56:23] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:23] → Inventory for 401952301 15/45 holds:
# [2022-11-10 09:56:23] →    montreal_02/401952301_006/SD6fw2106_20201120_134706.sdb
# [2022-11-10 09:56:24] →    Keeping montreal_02/401952301_006/SD6fw2106_20201120_134706.sdb
# [2022-11-10 09:56:24] →    Ingesting file: SD6fw2106_20201120_134706.sdb
# [2022-11-10 09:56:24] →    Keeping records within wear dates: 2020-10-15 - 2020-10-25 03:00:00.
# [2022-11-10 09:56:24] →    Loading tables for 401952301_SD6fw210620201120134706sdb_sd_gps
# [2022-11-10 09:56:26] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401952301_006/SD6fw2106_20201120_134706.sdb failed with return code: 127
# [2022-11-10 09:56:26] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:26] → Inventory for 401095730 16/45 holds:
# [2022-11-10 09:56:26] →    montreal_02/401095730_158/SD158fw2106_20201125_142018.sdb
# [2022-11-10 09:56:26] →    Keeping montreal_02/401095730_158/SD158fw2106_20201125_142018.sdb
# [2022-11-10 09:56:26] →    Ingesting file: SD158fw2106_20201125_142018.sdb
# [2022-11-10 09:56:26] →    Keeping records within wear dates: 2020-10-06 - 2020-10-16 03:00:00.
# [2022-11-10 09:56:26] →    Loading tables for 401095730_SD158fw210620201125142018sdb_sd_gps
# [2022-11-10 09:56:29] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401095730_158/SD158fw2106_20201125_142018.sdb failed with return code: 127
# [2022-11-10 09:56:29] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:29] → Inventory for 401664309 17/45 holds:
# [2022-11-10 09:56:29] →    montreal_02/401664309_063/SD63fw2106_20201202_163021.sdb
# [2022-11-10 09:56:29] →    Keeping montreal_02/401664309_063/SD63fw2106_20201202_163021.sdb
# [2022-11-10 09:56:29] →    Ingesting file: SD63fw2106_20201202_163021.sdb
# [2022-11-10 09:56:29] →    Keeping records within wear dates: 2020-11-10 - 2020-11-20 03:00:00.
# [2022-11-10 09:56:29] →    Loading tables for 401664309_SD63fw210620201202163021sdb_sd_gps
# [2022-11-10 09:56:36] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401664309_063/SD63fw2106_20201202_163021.sdb failed with return code: 127
# [2022-11-10 09:56:36] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:36] → Inventory for 401342134 18/45 holds:
# [2022-11-10 09:56:36] →    montreal_02/401342134_241/SD241fw0000_20010101_000000_rtc1.sdb
# [2022-11-10 09:56:36] →    montreal_02/401342134_241/SD241fw0000_20010101_000000.sdb
# [2022-11-10 09:56:36] →    Keeping montreal_02/401342134_241/SD241fw0000_20010101_000000_rtc1.sdb
# [2022-11-10 09:56:37] →    CAUGHT A SQL ERROR WHILE COUNTING RECORDS: file is not a database
# [2022-11-10 09:56:37] →    Skipping montreal_02/401342134_241/SD241fw0000_20010101_000000.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:37] →    Ingesting file: SD241fw0000_20010101_000000_rtc1.sdb
# [2022-11-10 09:56:37] →    Keeping records within wear dates: 2020-10-29 - 2020-11-03 03:00:00.
# [2022-11-10 09:56:37] →    Loading tables for 401342134_SD241fw000020010101000000rtc1sdb_sd_gps
# [2022-11-10 09:56:40] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401342134_241/SD241fw0000_20010101_000000_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:40] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:40] → Inventory for 401812917 19/45 holds:
# [2022-11-10 09:56:40] →    montreal_02/401812917_144/SD144fw2106_20210430_095356_rtc1.sdb
# [2022-11-10 09:56:40] →    montreal_02/401812917_144/SD144fw2106_20210430_095356.sdb
# [2022-11-10 09:56:40] →    Skipping montreal_02/401812917_144/SD144fw2106_20210430_095356_rtc1.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:41] →    Keeping montreal_02/401812917_144/SD144fw2106_20210430_095356.sdb
# [2022-11-10 09:56:41] →    Ingesting file: SD144fw2106_20210430_095356.sdb
# [2022-11-10 09:56:41] →    Keeping records within wear dates: 2020-12-15 - 2020-12-25 03:00:00.
# [2022-11-10 09:56:41] →    Loading tables for 401812917_SD144fw210620210430095356sdb_sd_gps
# [2022-11-10 09:56:42] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401812917_144/SD144fw2106_20210430_095356.sdb failed with return code: 127
# [2022-11-10 09:56:42] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:42] → Inventory for 402781880 20/45 holds:
# [2022-11-10 09:56:42] →    montreal_02/402781880_095/SD95fw2106_20210216_160113.sdb
# [2022-11-10 09:56:42] →    montreal_02/402781880_095/SD95fw2106_20210216_160113_rtc1.sdb
# [2022-11-10 09:56:42] →    Skipping montreal_02/402781880_095/SD95fw2106_20210216_160113.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:42] →    Keeping montreal_02/402781880_095/SD95fw2106_20210216_160113_rtc1.sdb
# [2022-11-10 09:56:42] →    Ingesting file: SD95fw2106_20210216_160113_rtc1.sdb
# [2022-11-10 09:56:42] →    Keeping records within wear dates: 2020-12-16 - 2020-12-27 03:00:00.
# [2022-11-10 09:56:42] →    Loading tables for 402781880_SD95fw210620210216160113rtc1sdb_sd_gps
# [2022-11-10 09:56:42] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402781880_095/SD95fw2106_20210216_160113_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:42] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:42] → Inventory for 402577721 21/45 holds:
# [2022-11-10 09:56:42] →    montreal_02/402577721_023/SD23fw2106_20210219_150125_rtc1.sdb
# [2022-11-10 09:56:42] →    montreal_02/402577721_023/SD23fw2106_20210219_150125.sdb
# [2022-11-10 09:56:43] →    Keeping montreal_02/402577721_023/SD23fw2106_20210219_150125_rtc1.sdb
# [2022-11-10 09:56:43] →    Skipping montreal_02/402577721_023/SD23fw2106_20210219_150125.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:43] →    Ingesting file: SD23fw2106_20210219_150125_rtc1.sdb
# [2022-11-10 09:56:43] →    Keeping records within wear dates: 2020-12-19 - 2020-12-30 03:00:00.
# [2022-11-10 09:56:43] →    Loading tables for 402577721_SD23fw210620210219150125rtc1sdb_sd_gps
# [2022-11-10 09:56:45] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402577721_023/SD23fw2106_20210219_150125_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:45] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:45] → Inventory for 402435135 22/45 holds:
# [2022-11-10 09:56:45] →    montreal_02/402435135_122/SD122fw2106_20210219_101230.sdb
# [2022-11-10 09:56:45] →    Keeping montreal_02/402435135_122/SD122fw2106_20210219_101230.sdb
# [2022-11-10 09:56:45] →    Ingesting file: SD122fw2106_20210219_101230.sdb
# [2022-11-10 09:56:45] →    Keeping records within wear dates: 2020-10-25 - 2020-11-04 03:00:00.
# [2022-11-10 09:56:45] →    Loading tables for 402435135_SD122fw210620210219101230sdb_sd_gps
# [2022-11-10 09:56:45] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402435135_122/SD122fw2106_20210219_101230.sdb failed with return code: 127
# [2022-11-10 09:56:45] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:45] → Inventory for 401809607 23/45 holds:
# [2022-11-10 09:56:45] →    montreal_02/401809607_049/SD49fw2106_20201120_103824_rtc1.sdb
# [2022-11-10 09:56:45] →    montreal_02/401809607_049/SD49fw2106_20201120_103824.sdb
# [2022-11-10 09:56:46] →    Keeping montreal_02/401809607_049/SD49fw2106_20201120_103824_rtc1.sdb
# [2022-11-10 09:56:46] →    Skipping montreal_02/401809607_049/SD49fw2106_20201120_103824.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:46] →    Ingesting file: SD49fw2106_20201120_103824_rtc1.sdb
# [2022-11-10 09:56:46] →    Keeping records within wear dates: 2020-10-14 - 2020-10-24 03:00:00.
# [2022-11-10 09:56:46] →    Loading tables for 401809607_SD49fw210620201120103824rtc1sdb_sd_gps
# [2022-11-10 09:56:47] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401809607_049/SD49fw2106_20201120_103824_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:47] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:47] → Inventory for 401379272 24/45 holds:
# [2022-11-10 09:56:47] →    montreal_02/401379272_169/SD169fw2106_20201124_161333.sdb
# [2022-11-10 09:56:47] →    Keeping montreal_02/401379272_169/SD169fw2106_20201124_161333.sdb
# [2022-11-10 09:56:47] →    Ingesting file: SD169fw2106_20201124_161333.sdb
# [2022-11-10 09:56:47] →    Keeping records within wear dates: 2020-10-16 - 2020-10-26 03:00:00.
# [2022-11-10 09:56:47] →    Loading tables for 401379272_SD169fw210620201124161333sdb_sd_gps
# [2022-11-10 09:56:48] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401379272_169/SD169fw2106_20201124_161333.sdb failed with return code: 127
# [2022-11-10 09:56:48] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:48] → Inventory for 401035210 25/45 holds:
# [2022-11-10 09:56:48] →    montreal_02/401035210_173/SD173fw2106_20201216_145827.sdb
# [2022-11-10 09:56:48] →    Keeping montreal_02/401035210_173/SD173fw2106_20201216_145827.sdb
# [2022-11-10 09:56:48] →    Ingesting file: SD173fw2106_20201216_145827.sdb
# [2022-11-10 09:56:48] →    Keeping records within wear dates: 2020-10-24 - 2020-11-03 03:00:00.
# [2022-11-10 09:56:48] →    Loading tables for 401035210_SD173fw210620201216145827sdb_sd_gps
# [2022-11-10 09:56:51] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401035210_173/SD173fw2106_20201216_145827.sdb failed with return code: 127
# [2022-11-10 09:56:51] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:51] → Inventory for 401328714 26/45 holds:
# [2022-11-10 09:56:51] →    montreal_02/401328714_201/SD201fw2106_20201215_164248.sdb
# [2022-11-10 09:56:52] →    Keeping montreal_02/401328714_201/SD201fw2106_20201215_164248.sdb
# [2022-11-10 09:56:52] →    Ingesting file: SD201fw2106_20201215_164248.sdb
# [2022-11-10 09:56:52] →    Keeping records within wear dates: 2020-11-15 - 2020-11-25 03:00:00.
# [2022-11-10 09:56:52] →    Loading tables for 401328714_SD201fw210620201215164248sdb_sd_gps
# [2022-11-10 09:56:53] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401328714_201/SD201fw2106_20201215_164248.sdb failed with return code: 127
# [2022-11-10 09:56:53] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:53] → Inventory for 401034573 27/45 holds:
# [2022-11-10 09:56:53] →    montreal_02/401034573_039/SD39fw2106_20201120_182540.sdb
# [2022-11-10 09:56:53] →    Keeping montreal_02/401034573_039/SD39fw2106_20201120_182540.sdb
# [2022-11-10 09:56:53] →    Ingesting file: SD39fw2106_20201120_182540.sdb
# [2022-11-10 09:56:53] →    Keeping records within wear dates: 2020-10-16 - 2020-10-26 03:00:00.
# [2022-11-10 09:56:53] →    Loading tables for 401034573_SD39fw210620201120182540sdb_sd_gps
# [2022-11-10 09:56:53] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401034573_039/SD39fw2106_20201120_182540.sdb failed with return code: 127
# [2022-11-10 09:56:53] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:53] → Inventory for 401860045 28/45 holds:
# [2022-11-10 09:56:53] →    montreal_02/401860045_237/SD237fw2106_20201216_140902.sdb
# [2022-11-10 09:56:53] →    Keeping montreal_02/401860045_237/SD237fw2106_20201216_140902.sdb
# [2022-11-10 09:56:53] →    Ingesting file: SD237fw2106_20201216_140902.sdb
# [2022-11-10 09:56:53] →    Keeping records within wear dates: 2020-10-28 - 2020-11-07 03:00:00.
# [2022-11-10 09:56:53] →    Loading tables for 401860045_SD237fw210620201216140902sdb_sd_gps
# [2022-11-10 09:56:53] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401860045_237/SD237fw2106_20201216_140902.sdb failed with return code: 127
# [2022-11-10 09:56:53] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:53] → Inventory for 402411342 29/45 holds:
# [2022-11-10 09:56:53] →    montreal_02/402411342_096/SD96fw2106_20201216_160332.sdb
# [2022-11-10 09:56:54] →    Keeping montreal_02/402411342_096/SD96fw2106_20201216_160332.sdb
# [2022-11-10 09:56:54] →    Ingesting file: SD96fw2106_20201216_160332.sdb
# [2022-11-10 09:56:54] →    Keeping records within wear dates: 2020-12-02 - 2020-12-13 03:00:00.
# [2022-11-10 09:56:54] →    Loading tables for 402411342_SD96fw210620201216160332sdb_sd_gps
# [2022-11-10 09:56:55] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402411342_096/SD96fw2106_20201216_160332.sdb failed with return code: 127
# [2022-11-10 09:56:55] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:55] → Inventory for 401919451 30/45 holds:
# [2022-11-10 09:56:55] →    montreal_02/401919451_235/SD235fw2106_20201120_185802.sdb
# [2022-11-10 09:56:55] →    Keeping montreal_02/401919451_235/SD235fw2106_20201120_185802.sdb
# [2022-11-10 09:56:55] →    Ingesting file: SD235fw2106_20201120_185802.sdb
# [2022-11-10 09:56:55] →    Keeping records within wear dates: 2020-10-09 - 2020-10-19 03:00:00.
# [2022-11-10 09:56:55] →    Loading tables for 401919451_SD235fw210620201120185802sdb_sd_gps
# [2022-11-10 09:56:58] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401919451_235/SD235fw2106_20201120_185802.sdb failed with return code: 127
# [2022-11-10 09:56:58] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:58] → Inventory for 402495712 31/45 holds:
# [2022-11-10 09:56:58] →    montreal_02/402495712_036/SD36fw2106_20201120_165446_rtc1.sdb
# [2022-11-10 09:56:58] →    montreal_02/402495712_036/SD36fw2106_20201120_165446.sdb
# [2022-11-10 09:56:58] →    montreal_02/402495712_036/SD36fw2106_20201120_165446_rtc2.sdb
# [2022-11-10 09:56:58] →    Keeping montreal_02/402495712_036/SD36fw2106_20201120_165446_rtc1.sdb
# [2022-11-10 09:56:58] →    Skipping montreal_02/402495712_036/SD36fw2106_20201120_165446.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:56:58] →    Keeping montreal_02/402495712_036/SD36fw2106_20201120_165446_rtc2.sdb
# [2022-11-10 09:56:58] →    Ingesting file: SD36fw2106_20201120_165446_rtc1.sdb
# [2022-11-10 09:56:58] →    Keeping records within wear dates: 2020-10-16 - 2020-10-26 03:00:00.
# [2022-11-10 09:56:58] →    Loading tables for 402495712_SD36fw210620201120165446rtc1sdb_sd_gps
# [2022-11-10 09:56:59] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402495712_036/SD36fw2106_20201120_165446_rtc1.sdb failed with return code: 127
# [2022-11-10 09:56:59] →    Ingesting file: SD36fw2106_20201120_165446_rtc2.sdb
# [2022-11-10 09:56:59] →    Keeping records within wear dates: 2020-10-16 - 2020-10-26 03:00:00.
# [2022-11-10 09:56:59] →    Loading tables for 402495712_SD36fw210620201120165446rtc2sdb_sd_gps
# [2022-11-10 09:56:59] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402495712_036/SD36fw2106_20201120_165446_rtc2.sdb failed with return code: 127
# [2022-11-10 09:56:59] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:56:59] → Inventory for 401240419 32/45 holds:
# [2022-11-10 09:56:59] →    montreal_02/401240419_077/SD77fw2106_20210216_110112.sdb
# [2022-11-10 09:57:00] →    Keeping montreal_02/401240419_077/SD77fw2106_20210216_110112.sdb
# [2022-11-10 09:57:00] →    Ingesting file: SD77fw2106_20210216_110112.sdb
# [2022-11-10 09:57:00] →    Keeping records within wear dates: 2020-12-09 - 2020-12-19 03:00:00.
# [2022-11-10 09:57:00] →    Loading tables for 401240419_SD77fw210620210216110112sdb_sd_gps
# [2022-11-10 09:57:00] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401240419_077/SD77fw2106_20210216_110112.sdb failed with return code: 127
# [2022-11-10 09:57:00] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:00] → Inventory for 402789603 33/45 holds:
# [2022-11-10 09:57:00] →    montreal_02/402789603_205/SD205fw2106_20210219_134504.sdb
# [2022-11-10 09:57:00] →    Keeping montreal_02/402789603_205/SD205fw2106_20210219_134504.sdb
# [2022-11-10 09:57:00] →    Ingesting file: SD205fw2106_20210219_134504.sdb
# [2022-11-10 09:57:00] →    Keeping records within wear dates: 2020-11-28 - 2020-12-08 03:00:00.
# [2022-11-10 09:57:00] →    Loading tables for 402789603_SD205fw210620210219134504sdb_sd_gps
# [2022-11-10 09:57:03] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402789603_205/SD205fw2106_20210219_134504.sdb failed with return code: 127
# [2022-11-10 09:57:03] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:03] → Inventory for 402141286 34/45 holds:
# [2022-11-10 09:57:03] →    montreal_02/402141286_293/SD293fw2106_20201120_145009.sdb
# [2022-11-10 09:57:03] →    montreal_02/402141286_293/SD293fw2106_20201120_145009_rtc1.sdb
# [2022-11-10 09:57:03] →    Skipping montreal_02/402141286_293/SD293fw2106_20201120_145009.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:57:03] →    Keeping montreal_02/402141286_293/SD293fw2106_20201120_145009_rtc1.sdb
# [2022-11-10 09:57:03] →    Ingesting file: SD293fw2106_20201120_145009_rtc1.sdb
# [2022-11-10 09:57:03] →    Keeping records within wear dates: 2020-10-22 - 2020-11-01 03:00:00.
# [2022-11-10 09:57:03] →    Loading tables for 402141286_SD293fw210620201120145009rtc1sdb_sd_gps
# [2022-11-10 09:57:16] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402141286_293/SD293fw2106_20201120_145009_rtc1.sdb failed with return code: 127
# [2022-11-10 09:57:16] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:16] → Inventory for 401097960 35/45 holds:
# [2022-11-10 09:57:16] →    montreal_02/401097960_121/SD121fw2106_20201215_172028.sdb
# [2022-11-10 09:57:17] →    Keeping montreal_02/401097960_121/SD121fw2106_20201215_172028.sdb
# [2022-11-10 09:57:17] →    Ingesting file: SD121fw2106_20201215_172028.sdb
# [2022-11-10 09:57:17] →    Keeping records within wear dates: 2020-11-10 - 2020-11-20 03:00:00.
# [2022-11-10 09:57:17] →    Loading tables for 401097960_SD121fw210620201215172028sdb_sd_gps
# [2022-11-10 09:57:19] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401097960_121/SD121fw2106_20201215_172028.sdb failed with return code: 127
# [2022-11-10 09:57:19] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:19] → Inventory for 401469801 36/45 holds:
# [2022-11-10 09:57:19] →    montreal_02/401469801_165/SD165fw2098_20201120_173723.sdb
# [2022-11-10 09:57:22] →    Keeping montreal_02/401469801_165/SD165fw2098_20201120_173723.sdb
# [2022-11-10 09:57:22] →    Ingesting file: SD165fw2098_20201120_173723.sdb
# [2022-11-10 09:57:22] →    Keeping records within wear dates: 2020-09-30 - 2020-10-13 03:00:00.
# [2022-11-10 09:57:22] →    Loading tables for 401469801_SD165fw209820201120173723sdb_sd_gps
# [2022-11-10 09:57:24] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401469801_165/SD165fw2098_20201120_173723.sdb failed with return code: 127
# [2022-11-10 09:57:24] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:24] → Inventory for 401440362 37/45 holds:
# [2022-11-10 09:57:24] →    montreal_02/401440362_167/SD167fw2106_20201120_154421.sdb
# [2022-11-10 09:57:24] →    montreal_02/401440362_167/SD167fw2106_20201120_154421_rtc1.sdb
# [2022-11-10 09:57:24] →    Skipping montreal_02/401440362_167/SD167fw2106_20201120_154421.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:57:25] →    Keeping montreal_02/401440362_167/SD167fw2106_20201120_154421_rtc1.sdb
# [2022-11-10 09:57:25] →    Ingesting file: SD167fw2106_20201120_154421_rtc1.sdb
# [2022-11-10 09:57:25] →    Keeping records within wear dates: 2020-10-28 - 2020-11-08 03:00:00.
# [2022-11-10 09:57:25] →    Loading tables for 401440362_SD167fw210620201120154421rtc1sdb_sd_gps
# [2022-11-10 09:57:36] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401440362_167/SD167fw2106_20201120_154421_rtc1.sdb failed with return code: 127
# [2022-11-10 09:57:36] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:36] → Inventory for 401811306 38/45 holds:
# [2022-11-10 09:57:36] →    montreal_02/401811306_246/SD246fw2106_20201125_162130.sdb
# [2022-11-10 09:57:37] →    Keeping montreal_02/401811306_246/SD246fw2106_20201125_162130.sdb
# [2022-11-10 09:57:37] →    Ingesting file: SD246fw2106_20201125_162130.sdb
# [2022-11-10 09:57:37] →    Keeping records within wear dates: 2020-10-16 - 2020-10-26 03:00:00.
# [2022-11-10 09:57:37] →    Loading tables for 401811306_SD246fw210620201125162130sdb_sd_gps
# [2022-11-10 09:57:37] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401811306_246/SD246fw2106_20201125_162130.sdb failed with return code: 127
# [2022-11-10 09:57:37] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:37] → Inventory for 401937896 39/45 holds:
# [2022-11-10 09:57:37] →    montreal_02/401937896_117/SD117fw2106_20201216_095149.sdb
# [2022-11-10 09:57:38] →    Keeping montreal_02/401937896_117/SD117fw2106_20201216_095149.sdb
# [2022-11-10 09:57:38] →    Ingesting file: SD117fw2106_20201216_095149.sdb
# [2022-11-10 09:57:38] →    Keeping records within wear dates: 2020-10-16 - 2020-10-26 03:00:00.
# [2022-11-10 09:57:38] →    Loading tables for 401937896_SD117fw210620201216095149sdb_sd_gps
# [2022-11-10 09:57:43] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401937896_117/SD117fw2106_20201216_095149.sdb failed with return code: 127
# [2022-11-10 09:57:43] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:43] → Inventory for 402958700 40/45 holds:
# [2022-11-10 09:57:43] →    montreal_02/402958700_166/SD166fw2106_20210224_164314_rtc2.sdb
# [2022-11-10 09:57:43] →    montreal_02/402958700_166/SD166fw2106_20210224_164314.sdb
# [2022-11-10 09:57:43] →    montreal_02/402958700_166/SD166fw2106_20210224_164314_rtc1.sdb
# [2022-11-10 09:57:44] →    Keeping montreal_02/402958700_166/SD166fw2106_20210224_164314_rtc2.sdb
# [2022-11-10 09:57:44] →    Skipping montreal_02/402958700_166/SD166fw2106_20210224_164314.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:57:45] →    Keeping montreal_02/402958700_166/SD166fw2106_20210224_164314_rtc1.sdb
# [2022-11-10 09:57:45] →    Ingesting file: SD166fw2106_20210224_164314_rtc2.sdb
# [2022-11-10 09:57:47] →    Keeping records within wear dates: 2021-01-30 - 2021-02-08 03:00:00.
# [2022-11-10 09:57:47] →    Loading tables for 402958700_SD166fw210620210224164314rtc2sdb_sd_gps
# [2022-11-10 09:57:48] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402958700_166/SD166fw2106_20210224_164314_rtc2.sdb failed with return code: 127
# [2022-11-10 09:57:48] →    Ingesting file: SD166fw2106_20210224_164314_rtc1.sdb
# [2022-11-10 09:57:49] →    Keeping records within wear dates: 2021-01-30 - 2021-02-08 03:00:00.
# [2022-11-10 09:57:49] →    Loading tables for 402958700_SD166fw210620210224164314rtc1sdb_sd_gps
# [2022-11-10 09:57:49] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/402958700_166/SD166fw2106_20210224_164314_rtc1.sdb failed with return code: 127
# [2022-11-10 09:57:49] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:49] → Inventory for 401967217 41/45 holds:
# [2022-11-10 09:57:49] →    montreal_02/401967217_102/SD102fw2106_20201125_095502.sdb
# [2022-11-10 09:57:51] →    Keeping montreal_02/401967217_102/SD102fw2106_20201125_095502.sdb
# [2022-11-10 09:57:51] →    Ingesting file: SD102fw2106_20201125_095502.sdb
# [2022-11-10 09:57:51] →    Keeping records within wear dates: 2020-10-15 - 2020-10-25 03:00:00.
# [2022-11-10 09:57:51] →    Loading tables for 401967217_SD102fw210620201125095502sdb_sd_gps
# [2022-11-10 09:57:53] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401967217_102/SD102fw2106_20201125_095502.sdb failed with return code: 127
# [2022-11-10 09:57:53] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:53] → Inventory for 401272178 42/45 holds:
# [2022-11-10 09:57:53] →    montreal_02/401272178_060/SD60fw2106_20201120_124137_rtc1.sdb
# [2022-11-10 09:57:53] →    montreal_02/401272178_060/SD60fw2106_20201120_124137.sdb
# [2022-11-10 09:57:53] →    Keeping montreal_02/401272178_060/SD60fw2106_20201120_124137_rtc1.sdb
# [2022-11-10 09:57:53] →    Skipping montreal_02/401272178_060/SD60fw2106_20201120_124137.sdb (Unacceptable dates: 0, 0, 0)
# [2022-11-10 09:57:53] →    Ingesting file: SD60fw2106_20201120_124137_rtc1.sdb
# [2022-11-10 09:57:53] →    Keeping records within wear dates: 2020-10-29 - 2020-11-08 03:00:00.
# [2022-11-10 09:57:53] →    Loading tables for 401272178_SD60fw210620201120124137rtc1sdb_sd_gps
# [2022-11-10 09:57:54] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401272178_060/SD60fw2106_20201120_124137_rtc1.sdb failed with return code: 127
# [2022-11-10 09:57:54] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:57:54] → Inventory for 401967735 43/45 holds:
# [2022-11-10 09:57:54] →    montreal_02/401967735_103/SD103fw2106_20201216_104036.sdb
# [2022-11-10 09:57:56] →    Keeping montreal_02/401967735_103/SD103fw2106_20201216_104036.sdb
# [2022-11-10 09:57:56] →    Ingesting file: SD103fw2106_20201216_104036.sdb
# [2022-11-10 09:57:56] →    Keeping records within wear dates: 2020-10-28 - 2020-11-07 03:00:00.
# [2022-11-10 09:57:56] →    Loading tables for 401967735_SD103fw210620201216104036sdb_sd_gps
# [2022-11-10 09:58:01] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401967735_103/SD103fw2106_20201216_104036.sdb failed with return code: 127
# [2022-11-10 09:58:02] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:58:02] → Inventory for 401796474 44/45 holds:
# [2022-11-10 09:58:02] →    montreal_02/401796474_189/SD189fw2106_20210219_121819.sdb
# [2022-11-10 09:58:02] →    Keeping montreal_02/401796474_189/SD189fw2106_20210219_121819.sdb
# [2022-11-10 09:58:02] →    Ingesting file: SD189fw2106_20210219_121819.sdb
# [2022-11-10 09:58:05] →    Keeping records within wear dates: 2021-01-16 - 2021-01-26 03:00:00.
# [2022-11-10 09:58:05] →    Loading tables for 401796474_SD189fw210620210219121819sdb_sd_gps
# [2022-11-10 09:58:11] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401796474_189/SD189fw2106_20210219_121819.sdb failed with return code: 127
# [2022-11-10 09:58:11] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:58:11] → Inventory for 401630460 45/45 holds:
# [2022-11-10 09:58:11] →    montreal_02/401630460_256/SD256fw2106_20201125_105925.sdb
# [2022-11-10 09:58:14] →    Keeping montreal_02/401630460_256/SD256fw2106_20201125_105925.sdb
# [2022-11-10 09:58:14] →    Ingesting file: SD256fw2106_20201125_105925.sdb
# [2022-11-10 09:58:16] →    Keeping records within wear dates: 2020-10-26 - 2020-11-05 03:00:00.
# [2022-11-10 09:58:16] →    Loading tables for 401630460_SD256fw210620201125105925sdb_sd_gps
# [2022-11-10 09:58:17] → Ingesting file /scratch/lazarou/test_pipeline/permanent_archive/Montreal/Wave2/SenseDoc/montreal_02/401630460_256/SD256fw2106_20201125_105925.sdb failed with return code: 127
# [2022-11-10 09:58:17] →    NO USABLE DATA CONTRIBUTED
# [2022-11-10 09:58:17] → All users' SDB files processed.

# %% [markdown]
# ### Verification
# As a final validation, compare the GPS and XLS tables to ensure that both have data from the same users.

# %%
with psycopg2.connect(user=db_user, host=db_host, port=db_host_port, database=db_name) as conn:
    cur = conn.cursor(cursor_factory=psycopg2.extras.RealDictCursor)
   
    mismatch_sql = f"""
        SET SCHEMA '{db_schema}';
        DROP TABLE IF EXISTS tmpgpsiids;
        DROP TABLE IF EXISTS tmpxlsiids;
        CREATE TABLE tmpgpsiids AS SELECT DISTINCT iid FROM sd_gps;
        CREATE TABLE tmpxlsiids AS SELECT DISTINCT iid FROM sd_accel;
        SELECT tmpgpsiids.iid AS gps_iid, tmpxlsiids.iid AS xls_iid 
        FROM tmpgpsiids 
             RIGHT OUTER JOIN tmpxlsiids 
             ON tmpgpsiids.iid = tmpxlsiids.iid 
        WHERE tmpgpsiids.iid IS NULL 
           OR tmpxlsiids.iid IS NULL;
        """
    
    print(f"\nFigure: SD users with data present in only one table\n")
    cur.execute(mismatch_sql)
    rows = cur.fetchall()
    if rows:
        print(tabulate(rows, headers='keys', stralign='right'))
    else:
        print('No mismatches found.')

    # Interact_id 302562672 is known to have no GPS data for SSK
    # Interact_id 201680208 is known to have no GPS data for VAN
    # Interact_id 402495712 is known to have no GPS data for MTL SD W2
# Out:
# Figure: SD users with data present in only one table
#
# No mismatches found.

# %% [markdown]
# Here endeth the ingest.
